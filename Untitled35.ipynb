# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import re
from time import sleep
profession = "数据工程师"
filePath = "职业信息.csv"
soft = ['职业', '工资','城市','工作经验','学历','公司名称','公司类型','链接']
sums = 40
def enter(driver,url):
    driver.get(url)
def find(driver,name):
    count=0
    driver.find_element_by_name('query').clear()
    driver.find_element_by_name('query').send_keys(name)
    driver.find_element_by_xpath(r'//*[@id="wrap"]/div[3]/div/div/div[1]/form/button').click()
    items=driver.find_elements_by_class_name('job-primary')
    lists=[]
    while(count<=sums):
        for i in items:
            good=[]
            link=i.find_element_by_tag_name('a').get_attribute('href')
            profession=i.find_element_by_class_name('job-title').text
            emolument=i.find_element_by_class_name('red').text
            city=i.find_element_by_tag_name('p').get_attribute('innerHTML').split('<')[0]
            work_experience = re.search(r'(?<=em>).*\w+(?=<em)',i.find_element_by_tag_name('p').get_attribute('innerHTML'))[0]
            education_background = i.find_element_by_tag_name('p').get_attribute('innerHTML').split('>')[-1]
            companyname = i.find_element_by_class_name('company-text').text.split('\n')[0]
            companytype = i.find_element_by_class_name('company-text').find_element_by_tag_name('p').get_attribute('innerHTML').split('<')[0]
            good.append(profession)
            good.append(emolument)
            good.append(city)
            good.append(work_experience)
            good.append(education_background)
            good.append(companyname)
            good.append(companytype)
            good.append(link)
            lists.append(good)
            print(good)
            count+=1
            if(count==sums):break
        if(count==sums):break
        next = driver.find_element_by_class_name('next').get_attribute('href')
        driver.get(next)
        #driver.find_element_by_xpath(r'//*[@id="main"]/div/div[3]/div[3]/a[5]').click()
        sleep(1)
        items = driver.find_elements_by_class_name('job-primary')
    return lists
def writeList2CSV(myList,filePath):
    try:
        file=open(filePath,'w+')
        myList.insert(0,soft)
        for items in myList:
            for item in items:
                file.write(item)
                file.write(",")
            file.write("\n")
        print("爬取成功!")
    except Exception :
        print("数据写入失败，请检查文件路径及文件编码是否正确!")
    finally:
        file.close()
if __name__ == "__main__":
    driver=webdriver.Chrome()
    enter(driver,"http://www.zhipin.com/")
    sleep(1)
    allInfo=find(driver,profession)
    writeList2CSV(allInfo,filePath)
    driver.quit()


# In[ ]:
# Out:
# ['数据挖掘高级工程师', '15-25K', '杭州 西湖区 三墩', '3-5年', '学历不限', '亚信科技', '计算机软件', 'https://www.zhipin.com/job_detail/0d93f7836a2bbb551XR43N27FFA~.html']
# ['数据库工程师', '9-14K', '杭州 西湖区 文一路', '3-5年', '本科', '美国道富', '互联网金融', 'https://www.zhipin.com/job_detail/d06e7684c61ea80803V50tS6ElI~.html']
# ['数据开发工程师', '18-28K', '杭州 西湖区 古墩路', '3-5年', '本科', '格家网络', '电子商务', 'https://www.zhipin.com/job_detail/3336aac2a137497203R52t-9FVc~.html']
# ['云数据库运维工程师', '30-60K', '杭州 滨江区 长河', '3-5年', '本科', '华为', '计算机软件', 'https://www.zhipin.com/job_detail/110ef50b028b407a1nN62tm6ElI~.html']
# ['数据库工程师', '15-25K', '杭州  ', '3-5年', '大专', '天玑科技', '数据服务', 'https://www.zhipin.com/job_detail/7ff8f9e9ec29474e1HB53dm5Elo~.html']
# ['数据挖掘工程师', '15-30K', '杭州 西湖区 古墩路', '5-10年', '本科', '格家网络', '电子商务', 'https://www.zhipin.com/job_detail/409d969b6c322e401Hx_3du8GVs~.html']
# ['数据可视化工程师', '25-50K', '杭州 滨江区 长河', '3-5年', '本科', '华为', '计算机软件', 'https://www.zhipin.com/job_detail/8a82f787bb868e9e1Xx_3d65GFQ~.html']
# ['数据库工程师', '12-18K', '杭州 拱墅区 上塘', '经验不限', '本科', '宽文是风', '计算机软件', 'https://www.zhipin.com/job_detail/5decf3518ea5528903Z53di7GFQ~.html']
# ['大数据技术支持工程师', '9-14K', '杭州 滨江区 长河', '1-3年', '本科', '浙江大华', '互联网', 'https://www.zhipin.com/job_detail/282252664309b9171nN90tS1FlU~.html']
# ['数据挖掘工程师', '20-40K', '杭州 余杭区 西溪', '1-3年', '硕士', '滴滴出行', '移动互联网', 'https://www.zhipin.com/job_detail/d7002ee2c851f70d1Xd539m5EVI~.html']
# ['数据工程师', '15-30K', '杭州 西湖区 西溪', '3-5年', '本科', '天壤智能', '互联网', 'https://www.zhipin.com/job_detail/a3a98c57c809da361X173Nu5FVU~.html']
# ['数据开发工程师', '14-28K', '杭州 西湖区 翠苑', '3-5年', '本科', '乐刻运动健身', 'O2O', 'https://www.zhipin.com/job_detail/a1994c6b31b8656a1XJ639W_EVc~.html']
# ['数据挖掘工程师', '18-28K', '杭州 西湖区 古墩路', '3-5年', '本科', '格家网络', '电子商务', 'https://www.zhipin.com/job_detail/3c801c9dcac3aa0503R52ty0F1I~.html']
# ['资深数据开发工程师', '18-30K', '杭州 余杭区 西溪', '3-5年', '本科', '大搜车', '互联网', 'https://www.zhipin.com/job_detail/d10703eb11ae6e3b1HB809y8E1c~.html']
# ['数据挖掘工程师', '15-30K', '杭州 西湖区 古墩路', '3-5年', '本科', '格家网络', '电子商务', 'https://www.zhipin.com/job_detail/1f84add1ba14f63e1X1-0t-_F1A~.html']
# ['数据仓库工程师', '15-25K', '杭州 滨江区 滨江区政府', '3-5年', '本科', '安恒信息', '信息安全', 'https://www.zhipin.com/job_detail/39f5852b9b3c97591HZz3ti_FlA~.html']
# ['数据库开发工程师', '6-10K·13薪', '杭州 西湖区 古荡', '1-3年', '本科', '华云科技', '计算机软件', 'https://www.zhipin.com/job_detail/fc4555e46f9b84851HN93Nq5EFc~.html']
# ['数据工程师', '10-15K', '杭州 西湖区 文三', '3-5年', '本科', '浙江协同数据', '数据服务', 'https://www.zhipin.com/job_detail/aa62e3db7870602803Vz3Ni_FVs~.html']
# ['数据开发工程师', '10-15K·13薪', '杭州  ', '1-3年', '本科', '联龙博通', '移动互联网', 'https://www.zhipin.com/job_detail/30baf47a8156463403Z92dS1FVc~.html']
# ['大数据运维工程师', '15-30K', '杭州 余杭区 仓前', '3-5年', '本科', '爱财集团', '互联网', 'https://www.zhipin.com/job_detail/f215c70dd7504a3c03Z_39q9GFQ~.html']
# ['资深数据开发工程师', '15-30K', '杭州 西湖区 文三', '3-5年', '本科', '嘉云数据', '移动互联网', 'https://www.zhipin.com/job_detail/4e8b14b173d85fcc1XFy29i8E1E~.html']
# ['数据库工程师', '10-20K', '杭州 余杭区 西溪', '3-5年', '大专', '学海教育', '计算机软件', 'https://www.zhipin.com/job_detail/89a34838303adfa81XJ52N-5GFo~.html']
# ['数据开发工程师', '12-24K', '杭州 余杭区 仓前', '3-5年', '本科', '耕云科技', '计算机软件', 'https://www.zhipin.com/job_detail/ac7753fc62b895031HN50tS6FFM~.html']
# ['GIS数据工程师(实习)', '3-4K', '杭州 余杭区 仓前', '经验不限', '本科', '经纬股份', '数据服务', 'https://www.zhipin.com/job_detail/ba19a34f48c56bc21Xdz2d-8F1E~.html']
# ['资深数据研发工程师', '20-40K', '杭州 余杭区 仓前', '3-5年', '本科', '阿里巴巴集团', '互联网', 'https://www.zhipin.com/job_detail/09a8c80ce1e446b31nZ_3t24GFs~.html']
# ['数据挖掘工程师', '20-40K·13薪', '杭州 西湖区 古墩路', '3-5年', '本科', '格家网络', '电子商务', 'https://www.zhipin.com/job_detail/152f5b1013be5f8e03Zz3tW9EFY~.html']
# ['高级大数据工程师', '20-35K', '杭州 西湖区 黄龙', '5-10年', '硕士', '深大智能', '旅游', 'https://www.zhipin.com/job_detail/62ce3adf2a08b3421Hd52ty0FFQ~.html']
# ['大数据研发工程师', '12-24K', '杭州  ', '1-3年', '本科', '浙江大华', '互联网', 'https://www.zhipin.com/job_detail/f5a32fb8e759199e1nB63ty5GQ~~.html']
# ['资深数据挖掘工程师', '22-35K·14薪', '杭州 西湖区 文三', '1-3年', '硕士', '嘉云数据', '移动互联网', 'https://www.zhipin.com/job_detail/bdd6b7a1aa3157f61Hd93NS4F1c~.html']
# ['数据挖掘工程师', '20-40K', '杭州 西湖区 古荡', '1-3年', '硕士', '蚂蚁金服', '互联网', 'https://www.zhipin.com/job_detail/347c92c001446a451Hd439W0Fls~.html']
# ['大数据开发工程师', '12-24K', '杭州 滨江区 浦沿', '3-5年', '本科', '杭州三汇', '计算机软件', 'https://www.zhipin.com/job_detail/dcd21c85d8851cb003V62NS1FFA~.html']
# ['数据挖掘工程师', '15-30K', '杭州 拱墅区 古墩路', '3-5年', '本科', '米橙科技', '移动互联网', 'https://www.zhipin.com/job_detail/535c3eb3c644ab9f0nV529m5EQ~~.html']
# ['数据平台工程师', '15-30K', '杭州 滨江区 滨江区政府', '3-5年', '本科', '企加云CRM', '计算机软件', 'https://www.zhipin.com/job_detail/0cd6ee068238688e1XJ72dy1GVs~.html']
# ['数据库工程师', '6-10K·13薪', '杭州 拱墅区 拱宸桥', '经验不限', '本科', '上海天正', '计算机软件', 'https://www.zhipin.com/job_detail/3b28bddd304758801HR829-6F1Y~.html']
# ['数据仓库工程师', '15-30K', '杭州 西湖区 古荡', '3-5年', '本科', '格家网络', '电子商务', 'https://www.zhipin.com/job_detail/055e90858d4641891HR72tW9FVE~.html']
# ['数据挖掘工程师', '25-40K', '杭州 滨江区 长河', '3-5年', '本科', '浙江连信科技有限公司', '移动互联网', 'https://www.zhipin.com/job_detail/b61c3e9d6a07e7da1Hd-09m7EVY~.html']
# ['数据服务工程师', '15-25K', '杭州 西湖区 转塘', '3-5年', '本科', '数梦工场', '数据服务', 'https://www.zhipin.com/job_detail/fb360c2dc605daf81XBy2Ni0E1A~.html']
# ['大数据运维工程师', '20-40K', '杭州 西湖区 古荡', '3-5年', '本科', '有赞', '互联网', 'https://www.zhipin.com/job_detail/ecedd51f39fb9b451n1_3t27FFY~.html']
# ['数据ETL工程师', '20-35K·16薪', '杭州 西湖区 古墩路', '3-5年', '本科', '格家网络', '电子商务', 'https://www.zhipin.com/job_detail/908b85c7840dba901H150t26FFY~.html']
# ['大数据工程师', '15-20K', '杭州  ', '3-5年', '本科', '浙江大华', '互联网', 'https://www.zhipin.com/job_detail/a8bd4a588cf7411b1HJ82dm9GVU~.html']
# 爬取成功!
