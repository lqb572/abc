# %%
#%%
import subprocess
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
import re,time

#%%
command = "\"C:\\Program Files (x86)\\Google\\Chrome\\Application\\chrome.exe\" --remote-debugging-port=9242 --user-data-dir=C:\chrome_profile"
print(command)

#%%
retcode = subprocess.Popen(command,shell=True)

#%%
time.sleep(10)

#%%
chrome_options = Options()

#%%
chrome_options.add_experimental_option("debuggerAddress", "127.0.0.1:9242")

#%%
driver = webdriver.Chrome(options=chrome_options)

#%%
driver.get("https://item.jd.com/969152.html")

#%%
driver.find_element_by_xpath(r'//*[@id="detail"]/div[1]/ul/li[5]').click()

#%%
reobj = re.compile(r'<p class="comment-con">([\s\S]*?)</p>')

#%%

#%%
comment = []
count = 1

#%% 
# driver.find_element_by_xpath(r'//*[@id="comment-0"]/div[13]/div/div/a[6]').click()

# driver.find_element_by_link_text(u"下一页").click()


# if 'click' in dir(driver.find_element_by_link_text(u"下一页")):
#     driver.find_element_by_link_text(u"下一页").click()
#     print("true")



#%%
def next_page(driver):
    # driver.find_element_by_link_text(u"下一页").click()
    parent = driver.find_element_by_css_selector('.ui-page')
    try:
        parent.find_element_by_link_text(u"下一页").click()
    except:
        time.sleep(2)
        page_num = parent.find_element_by_link_text(u"下一页").get_attribute('rel') 
        # ActionChains(driver).send_keys(Keys.SPACE).perform()
        # time.sleep(2)
        parent.find_element_by_link_text(page_num).click()
        # driver.find_element_by_link_text(u"下一页").click()

#%%
while True:
    html = driver.page_source
    result = reobj.finditer(html)
    if not result:
        print("找不到评论结束")
    for i in result:
        comment.append(i.group(1))
        print(str(count) + ".\t" + i.group(1))
        count += 1
    # for i in result:
    #     z = reobj1.search(i.group(1))
    #     try:

    #         comment.append(z.group(1))
    #         print(str(count) + ".\t" + z.group(1))
    #         count += 1
    #     except:
    #         pass
    # retry = 0
    
    try:
        next_page(driver)
    except:
        try:
            next_page(driver)
        except:
            break
##-----------------
#    for p in Page_turning.find_elements_by_tag_name("a"):
#        ActionChains(d).move_to_element(p).perform()
#    retry = 0
#    for j in range(0,5):
#        try:
#            time.sleep(2)
#            p.click()
#        except:
#            retry += 1
#    if retry > 4:
#        print(retry)
#        break                

#%%
# result = reobj.finditer(html)
# for i in result:
#     print(i)

#%%
print(i.group(1))



#%%
len(comment)

#%%
with open('d:\\ssssss9.csv','w+',encoding='utf-8') as f:
    for i in comment:
        data = str(i) + ',\n'
        f.write(data)

#%%
# Out:
# "C:\Program Files (x86)\Google\Chrome\Application\chrome.exe" --remote-debugging-port=9242 --user-data-dir=C:\chrome_profile
# 1.	用了一段时间来评价的，网上查询了，正品无疑！刚收到打开看到耳机线很短！很脆弱的感觉，不过使用过后觉得还行，随身携带放兜里线材刚刚好，个人觉得这样设计还是有可取之处的！说说效果，我这个开声干净，解析好，声场跟分离都很强大?，有人说开声糊，开始我还怀疑买到假货了，后来煲了一段时间，总体很满意，声音是无可挑剔的了，之前用艾利和米歇尔，感觉这个秒杀艾利和！
# 2.	非常好的耳塞，不愧是深海赛尔的，旗舰机型，第一低音比较有弹性，中音通透高音，很明亮，非常适合古典，和人生看电影也很舒服，最重要的是低音量，虽然不大，但是非常的有弹性，给人感觉很好
# 3.	一耳朵的均衡体验，较ie800中频的提升非常明显，人声贴近谢兰图，没有短板，声场宽广，鼓点圆润富有弹性，低频下潜足够，完美诠释动圈之王
# 4.	非常好这个是第二条耳机800听重金属纯音乐乐器都很满意服务也特别好喜欢就值得祝大家年年#
# 5.	很好，听起来很舒服，已经宝鸡100小时，跟刚开音完全不同，声场很广，低音也很舒服，总之值了，没有对象就是爽，想买啥买啥，但是跟父母还是要保密的，这耳机几十块，不对，十几块，嗯就是十几块。
# 6.	手上最好听的塞子，不吃前端，好推，小小腔体爆发力惊人，入耳舒适，轻便如若无物，在D100下不到一星期就出声了，D I Y线材一根，音质提升显著，塞子较为娇气，听诊器明显，不出街，就留在家里玩了，很喜欢！
# 7.	包装：符合真品一切特征。真伪：拿到了就扫码查询森海塞尔官网，确定真品无误。<br />产品：50000号以后的产品，传说中的线硬没有发现，软硬适中。<br />声音：IE 80用了几年，800乍一听明显还是森海塞尔的声底，因为刚开声没有特别感觉，总之没让人失望也没有绝对的惊喜，声场很大、低音比80强、解析度很高没有隔雾感，煲煲再看相信越来越好。<br />好评！
# 8.	接上我的SONY D100开声，《加州旅馆》《王菲 天空》试声，和IE800搭配的很好，音量2感觉就推开了，声音大没有轰头的感觉，低音下潜很深。不愧是森海塞尔旗舰！
# 9.	非常好,戴着也很合适,音质就不多说了,已经有无数的人测评过,确实很好
# 10.	很好，声音非常干净，通透，还要煲开，会更好。这个线子我是真的无语，中间这段如果是一体的，会更好
# 11.	送老公的生日礼物 他出门耳机是必备品 超喜欢音乐对音质要求也比较高  希望煲机之后可以达到完美的效果  好评
# 12.	期待以久的旗舰耳塞，终于完美地呈现在眼前，喜悦之心自难描述。小心地打开包装，迫不及待的接上播放器，美妙温暖的音乐喷泉而出！没错，是正品。声音还原真实，低频厚实下潜很深，高频清晰通透不刺耳，中频有毒，听古典音乐一流，小体量大能耐。听着听着忘了下班，要不是保安要锁门提醒，可能听一个晚上！
# 13.	很不错，是我想要的音质，低频量足，下潜深，高频靓丽，中频也还行，和所选歌曲有关，好的一副耳机确实能听到很多细节，值了，华为手机推的，播放器推更好!
# 14.	物流很快，刚收到，包装很好，耳塞小巧精致，开始试听、煲机。如愿，好评！
# 15.	惊艳至极！全新未拆封有少许运输磨损！made in Germany编号4万多了！开箱后觉得IE800这么小的耳机怎么会值得那么多钱？用Sonyzx100直推试听了男声赵鹏和蔡琴低音酥到极致， 头皮都酥了，就要这种感觉！一般女声感觉歌手舌头晃动、轻微换气的声音都能听清，仿佛能感觉声音从哪个齿缝出来一样！解析力相当细腻通透！！！不愧为旗舰，王者！古典和乐器声场十分宏大下潜很深！初听已经非常不错，慢慢煲，肯定能满足了，入耳式的王者了。（PS:之前试听过同事渔夫的z5，绝对没有这个好，虽然索尼的线材非常非常好，但是音质还是没法和森海塞尔抗衡！这个给在两者间犹豫徘徊的人一些参考！）
# 16.	音质很好，一直是森海的粉，从PX100，IE8到IE800，声音比IE8清澈了很多，没有那么多低频，声音也没有那么混，听有些歌曲还是挺震撼。包装的很简单，盒子感觉应该没有拆开过，还没有查防伪。感觉值这个价了。
# 17.	解析力无敌啊…拆包初一听就非常棒了。声音偏冷，高频低频都很突出。听流行也没有说得那么糟。个人感觉要比K3003和SE846要适合自己。不过确实是很难推，考虑入手的要有个好音源。
# 18.	刚买回来音质就秒了我的iPhone6耳机！不愧是三大旗舰之一！不过现在只能用iPhone推了！先委屈一下你。过几天再买索尼大法zx100！这耳机阻抗低，iPhone也是可以推的。先煲它两百小时再来追加音质评论吧！我是德粉！森海塞尔粉丝！从MX985到大馒头二代！如今终入手旗舰可以退烧了！京东价格还是满意，肆陆肆柒玖！加上12期免息！京东物流给力！隔天到！
# 19.	儿子长草了很久，趁着618，价格优惠，忍不住下手了。3299入手。第二天就收到货了，原厂包装，正品。音色很好，特别是重音效果。儿子满意就行。
# 20.	刚拿到手拆开试听，貌似很平庸，手感一流，可能听80听多了，有种一脉相承的错觉
# 21.	总体来说 又爱又恨 音质不多说了 太多的评论 一个字 好，和846对比了一下，846更好推些，隔音效果更好，音色来说 更喜欢森海的柔和，通透，磁性，说下缺点，设计的大师可能没考虑佩戴人群耳朵的通用性，我试了很多人 都是坐在那里不动 带着还能坚持听一会儿 一动就掉，各种大小规格的耳塞都试过了，真的让人无语，也想了很多办法 最后采取的是图上安装好的佩戴方式为最佳，当然别忘了加个夹子减少听诊效果
# 22.	森海塞尔IE800，旗舰耳机，没有缺点，没有听诊器效应，线用料和做工非常好，产地是德国的。京东物流很快，服务很好。
# 23.	IE800旗舰，退烧了
# 24.	与索尼Z5相比完胜。这个黑科技的耳机小巧漂亮配带舒服音色自然亲切，无论是三星S8+海贝播放无损音乐还是索尼黑砖4.4平衡播放DSD效果都很好。上放跟旗舰800s对比确定声音走向是一致的。
# 25.	煲开了以后的声音实在是太帮了，绝对对得起这个价格；外观也很漂亮（虽然不是出街用）；配件丰富，送的耳机包材质很不错，也相当好用。另外一定要配合好的前端加耳放，会听到让人更惊艳的声音。
# 26.	收到后试听，感觉世界一下干净了，中高低音表现都很出色，不是发烧友，但很满足！售后服务很棒，买后降价，有保价保障，赞一个！
# 27.	帮朋友买的耳机，他很喜欢，说听到歌曲中以前没有的小细节，煲机后希望更完美。
# 28.	这个必须重点评价一下 我买过很多耳机 这个真的是非常值得入 人声非常清晰 携带方便 好 就一个字！
# 29.	快递一个字，快，提前一天送到。耳机音质超好，一分钱一分货，清晰干净。做工精美，艺术品一般。
# 30.	忠实森海粉从阿姨80s升级到800真的是非常值了！解析力，声场，瞬态，通透性，这几点上的提升可以说是让我退烧了！听歌杂食啥都听，流行满意，古典大场面惊艳！今天还特地去Sony实体店对比了zx300是不是比果x推的更好，最终结果125的灵敏度x完全够了，和zx300无差~好评！
# 31.	森海塞尔的耳机挺好的，棒棒的，不愧是精品！质量感觉还不错！希望京东服务越来越好，优惠多多，棒棒哒！非常好！
# 32.	京东网购体验非常愉快，特别是京东自营，宝贝正品无疑，编号5万+，而且快递也给力，手上没有什么好的前端，听感已经觉得不错了，期待搭配后有更好的表现。
# 33.	这个耳机很久就想买，一直舍不得买，担心质量。因为我之前买了很多耳机，有森海七百多的，也有国产得胜，慢步者，还有国外索尼，飞利浦。从二三百到一千三。都不是很满意。这次下决心买了这款三千多大洋，有点心疼。刚收到一听，吓我一跳，比之前的耳机没有什么不同。只好耐心听几天，过了一个星期再来听其它耳机感觉有差距了。这耳机音质越来越好非常通透。再用专业声卡做前端声音越来越美。继而在网上下载无损国外音乐和国内的高音质歌曲，让人几乎听歌上瘾了。全五星好评，看来一分钱一分货不假。
# 34.	一直很喜欢森海家的耳塞，每次换的动圈也都是森海家的，不错～感觉800更适合乐器，耳塞中频感觉偏凹陷～
# 35.	可以说是非常森海了，欠煲，煲开声了以后一定很惊艳。现在已经比80清澈多了。对人声一如即往的不友好。
# 36.	包装盒全新、无拆封。<br />试听了下，音质非常棒棒，把手上的索尼旗舰XBA-H3和Beats solo3甩到不知道哪里去了。
# 37.	我之前用的是80，这次元旦看到优惠那么大直接入了800，真是一耳朵的惊喜，高音通透解析力高，目前用手机推的还不错，等声音完全开了再考虑播放器。总之非常值，现在80只能吃灰了
# 38.	刚收到货时一听，还以为被调包了，完全跟几百元的塞子一样，非常担心，后来煲了4-5小时后再听，完美。
# 39.	物流快，耳机很满意，一直都想买的QAQ，声音很喜欢…<br />对了，线现在已经不硬了，还挺软的。
# 40.	耳机很酷，声音分辨性很强，目前在使用中，新感受以后再说
# 41.	在家里用ipad直推，软件用的~云音乐。效果和以前用的ckr10差不多，听dj流行改不如ckr10.但是听古典很好，比如吕思清的。
# 42.	双11活动还真实惠，好几年了，现在非常信赖京东，放心啊。IE800名不虚传，刚买来就感觉了一下，那声音真是通透，比我以前的IE80要好。
# 43.	快递很给力，拿到手第一时间查询了真伪，买了就为了听流行，不要相信网上的一些评测，自己的听感最重要
# 44.	音质没得说，这个价格算是很有性价比了。耳机小巧精致，做工精细。
# 45.	安卓手机不能推，底噪不能忍，慎买<br />大概今天终于煲开，呈现出令人惊艳的声音，非常满意。解析的话不会说，但素质远超以前听过的耳机。值回票价。<br />赞一个京东的客服，物流，保价和组合支付
# 46.	一直担心买回来用手机放不好听，但听了之后效果还是很棒的!   舒服
# 47.	说句实话 ie800从7800+的价格就开始关注 一直等到现在这个价格入。虽说出800s了……但是对于800绝不会让烧友失望。声音真的很棒，比ie80 80s强太多 值！ Z2完美推！ 哈哈 退烧了退烧了！
# 48.	很好很准时的京东快递。货品第一感觉是官方正品，还没注册。听了一晚上孙露的黑胶，转盘的沙沙声能还原的清楚，比XBA_Z5的稍微好上一层次。
# 49.	很喜欢  很漂亮 音质不错 带上耳朵不疼
# 50.	森海的旗舰耳机，音质没得说！特意听了近一个月才来评价，非常满意！音质确实对得起这个价格。
# 51.	买了许久才来评价，音质很棒，比ie80s强太多，性价比很高
# 52.	真的不错，这一款到现在已经算性价比非常高了，第一耳朵感觉就很好，尤其是低音。总体感觉乐器越多，越复杂，尤能突出优势，尤其是大编制的交响乐，层次清楚，定位准确。
# 53.	刚开始拿到的时候是真的不能听，完全没活动开，听了两天还没开始刻意的煲已经好很多了，手机听50一下音量没什么效果，达到60以上勉强可以听了。细节很细腻，越来越好中
# 54.	对于大编制和乐器确实很不错，人生不敢恭维。总体很满意，小馒头可以退役了。
# 55.	双十一打折，性价比很不错，音质很不错，配合我的sony黑砖，绝配
# 56.	3003正好春节前坏了，买了个同时代的旗舰过节，弦乐最棒。线材很棒，稍短了点。
# 57.	在这个少了祝福少了陪伴的节日里，多了与森海塞尔ie800s的邂逅带来的快乐，让我别无他想，这一天必将难忘。用森海也好几年了，也用过了几款森海的耳机，这款耳机第一次听就感觉很爽，以前从未有这种感觉。很满意的购物！
# 58.	很早就想买800了，因为之前有一副80很赞。800比80的提升太明显了，双十一搞活动咬牙就入了。物流也很快
# 59.	一定要来评价<br />真的太震撼了<br />仅仅用mate9播放<br />已经被带进了大剧院<br />大气场 大场面<br />气势恢宏 磅礴<br />身临其境 细节清晰<br />以后可以不用去现场听音乐会了了！
# 60.	物流很快，外包装看起来没毛病，是新的，现在正在煲机，500小时后再来追评。
# 61.	音质没的说。降噪效果很OK，一个人听歌逛街跑步超赞啊
# 62.	收到货物后，开箱惊艳，试听效果真的很好。用索尼300听交响乐比索尼1a大耳好的多！只是京东商城价格变化太大，让人难以接受！
# 63.	包装完整，开箱惊艳，音质一流，不亏大牌！
# 64.	听歌声音是一种质的飞跃，感觉很棒，包装精美，耳机盒做工也很好
# 65.	很不错到底是旗舰，之前有ie80，这次ie800也有惊喜，很值得。
# 66.	昨晚下的订单，今天到货，快递很快，耳机声音如何还不知，煲后再评。
# 67.	快递包装很随意，产品包装外壳也很普通，作风倒是很低调，音质不错，我是拿手机或笔记本直推的，果然是同价位听大编制古典的神器，很满意。
# 68.	花了好多好多钱的时候才知道京东评论的重要性，所以以后我不管买什么宝贝，我都会把这句话复制粘贴下来，然后在填写宝贝的评论。客服态度很好，整体来说比较满意，很愉快的一次购物，也许我还会再来，有问题就会追评。
# 69.	哇，果然是800，低音一如既往的好，高音也很甜，一首Next to you 完全体现出了800的优势，当然，中频人声还需要加强，再煲着试试看。
# 70.	一耳朵的提升，用iPhone直推也比EX1000好很多，再配合一个好点的前端就可以暂时退烧了，看来HIFI这东西只能靠耳朵收货最靠谱，只希望耐用点
# 71.	那些专业术语什么的 我说不出来 一向对京东很满意 很喜欢它的外观 尤其是耳机收纳包 买它就是想一步到位 估计快停产了 怕以后买不到了 s什么的太贵...
# 72.	耳机还是很不错的，比较喜欢听古典，耳机煲了有两星期了，音质也在稳定提升，很不错
# 73.	这耳机音质不用说，很好，很喜欢，遗憾的是佩戴感不行，听歌的时候头稍微一动耳机就会滑落，让人很恼火，希望森海塞尔厂方尽早解决这个大问题，给消费者最满意的使用感受。
# 74.	看了很多评测，很喜欢这款小耳机，双十一没能抵挡住特价的诱惑，买了一副。外包装就一塑料袋，还好商品无损坏，希望这点能改进下。耳机原装正品，初听解析度高，但听感不如煲好的一般耳机动听，看来欠煲。开始漫长的500小吋煲机之路，期待美妙动听的音乐。能够以惊爆价买到喜欢的耳机，还是很开心的。
# 75.	全新未拆过，拿来手机听歌的。声音很满意！其他的我也不懂。
# 76.	看着是正品，也查了验证，不错。刚刚开始听，效果不会给人明显的惊喜，看后续煲开后什么效果再做评价。耳塞太小了，睡觉听的时候，耳塞很容易就掉出来。
# 77.	很不错，帮同事买的，音质挺好。快递配送也快，赶在双十一前买
# 78.	线很软，音质不错，新耳塞高中低都不错，中频也不远，除了移动佩戴外超级满意
# 79.	第一次买如此贵的耳机，效果真不错，如此小的玩意，声场这么大，真的特别不容易。声音很透亮，对比我的威士顿w40，解析力大福提升，很不错！
# 80.	之前都是用头戴比较多，刚刚拿到手，木耳暂时没有听到很惊艳的效果，不过用ak100II推的效果还是比一些中档设备好太多了，尽管还没有煲开，相比之前用同学的ie80s要厚实很多，感觉80s的声音略显单薄，低音有些空，震撼感不强烈，目前还在用轻音乐来煲，人声暂时不了解，相信煲开了之后不会叫我失望，听说这款耳机欠煲得很，所以还是期待满满呢，快递的速度也是非常的快，客服也很耐心，五星了
# 81.	高端耳机就是不一样，玩法很多，音质也不用说。我测试了耳朵的层次，结果还不错。
# 82.	音质很棒，刚买的少了配件售后立马就给换了，特别棒的购物体验，满分
# 83.	考虑再三，还是京东旗舰店可靠。感谢！！！<br />防伪标识满满。线很软。音清透。<br />赞赞赞
# 84.	非常好，音质比IE80有很大提升，低频表现最出色，下潜深，低频清晰有弹性，高音有齿音，煲了160个小时左右已经有明显改善，IE800一直被烧友所诟病的中频，我觉得还行，两头翘中间低这种调音，我的耳朵可以接受，看各人的听感了，我还是很满意的，可以退烧了！
# 85.	非常完美，解释度高，比ie80好很多
# 86.	憧憬这副塞子很久了 今天有幸入了  开声就很满意  往日后表现俱佳
# 87.	终于入了IE800S，这腔体大小发出的声音简直是令人不可思议，满分好评，煲机中
# 88.	物流很快，包装不错，铭牌，很漂亮，耳机还没煲开有点闷，但声音很清晰。
# 89.	很喜欢，现在手里没有能推动它的，暂时用电脑推，每晚电脑都不关机煲它一晚上，期待以后配个旗舰前端可以退烧了
# 90.	这才是传说中的退烧神器，这就是我想要的声音，各方面非常满意！
# 91.	刚收到货，做工非常的精致，而且非常的小巧，，希望能够有很好的音质。
# 92.	价格外实在是太贵了,就这么小小的小东西花了我5699!<br />不过,东西确实是很好!!非常喜欢!800解析度非常强,声音十分干净,比我的DT990解析和纯净度明显强一大截!喜欢的不得了!买之前在800和AKG3003之间摇摆不定,看了若干人的评价,最后还是决定买更早出品的800.也幸好是选了800,要不就变成刚买3003,马上就得被它降价500气得吐血呀........!
# 93.	森海 四大品牌之一，音质非常完美。唯独包装一般，没塑封和圆封。
# 94.	很好呀 暂时还在听 很喜欢 解析力非常强
# 95.	赶上双11活动，3788减211券真便宜，比全球购还便宜，然后又返3000多京豆。耳机初听不如ie60,但是煲机30小时了，声音越来越好，对于这个价格这个素质很满意。
# 96.	很棒棒，比之前的 N1不知道高到哪里去了
# 97.	刚拿到第一耳朵真的很闷很闷，听了两个小时好点~再听听看吧~
# 98.	东西很好，也没中奖。是全新的，方位也查过了是第一次查询。音质方面不说了要不是真喜欢也不会花这么多钱买下来，总之很符合我的耳朵。
# 99.	送老公做生日礼物，特别开心，老公很喜欢，说是听出了金钱的味道～哈哈哈！
# 100.	宝贝质量很好 音质没的说 听着舒服 价位也没得说
# 101.	我的ie800煲开了，真心不错，继承了动圈的所有优点，跟动铁的优点比也一点不逊色。真心值得推荐。<br />
# 102.	质量不错，发货速度也很快，本人非常喜欢，观望的朋友赶紧下单吧！不要犹豫了，好评！支持京东自营产品。
# 103.	第一次买高端耳机。音质确实很?b，还在煲机中。希望以后音质完美呈现
# 104.	包装精致，耳塞质量很好。希望煲过之后能有大的提升。
# 105.	包装完整，耳机不错，刚开音就很惊艳，佩戴不是特别舒服，加个线夹佩戴，出外完美。
# 106.	IE800声场很宽 比IE60强很多 新塞子齿音还比较重 煲机中 相信煲开素质会不错
# 107.	音质方面不错就是听诊器效果真的给力，碰下线就有很大的声音，配了个线夹好很多
# 108.	耳机很小巧，轻盈，线材相对IE80要好很多。初听就能感觉到很强的解析力，但低音还不足，潜力应该会很大，毕竟不便宜。
# 109.	专门用来吃鸡用的耳塞！ 聆听脚步声反潜行很棒啊！ 吃鸡神器 哈哈哈~~~~
# 110.	声音很好，iphone直推交响乐很好听
# 111.	非常好。收到货很喜欢。很不错。5星好评。推荐推荐推荐
# 112.	佩戴很舒适，手机上听也比原装耳机高几个档次，不错
# 113.	目前是性价比最高的选择吧，很满意
# 114.	很好用很好用，下次再来。非常给力的耳机，不要膜拜动铁，动圈也有很NB的耳机
# 115.	初听声音就很好，说不上惊艳，只感觉舒服，果然一分钱一分货。物流得力，很满意。只是包装大简了，与价位不配。
# 116.	初次开声不错，异物感很轻，煲好自己改平衡
# 117.	IE800相对来说不那么适合听流行音乐，听弦乐很赞，解析非常好，是个既挑音源又挑歌曲的货色，动态及瞬态太好了，隐隐有大耳机的样子。
# 118.	耳机非常好，用料扎实，做工精良，音质很棒。
# 119.	超震撼的，没想到这么小的耳机声场这么大，做工与声音都满意
# 120.	已经收到，正在煲机，看着很小巧的样子……期待音质！是真品！
# 121.	耳机做工优良，解析很意外，低频强劲，高频差点意思，总体很优秀
# 122.	刚买回来的时候是听了一下效果感觉真的很不咋样，耐心的包了50个小时以后就感觉明显好很多，现在的音质越来越进入家近了，特别要说的是这款耳机的低频真心的好。总而言之非常满意的一次购物
# 123.	退烧药，对其他的耳机没有了欲望，做工精细，佩戴舒服，手机直推，完美享受。
# 124.	非常好的一次购物，送货很及时，产品包装完好，还没有煲机，待煲机之后在做评论。但希望送货小哥可以及时送货。
# 125.	很好，这个一定要有耐心，煲几天好很多，非常满意
# 126.	老顾客了，好用方便，质量感人，个人很喜欢。
# 127.	超级好用，超级好用，超级好用，超级好用，超级好用，音质超好
# 128.	包装是个惊喜，居然没有密封封条，出乎我的意外，对于京东自营的商品，真假我一直都是信赖的
# 129.	真的很小巧，没有说的佩戴问题，低音有惊喜。
# 130.	德国技术精湛 音质效果真心好 真不错?
# 131.	很棒，活动优惠力度很大 值得购买 音质很棒
# 132.	很好的耳机觉得比w60要好不少呢 超棒
# 133.	从UE、铁三角到森海，各有各的风格，耳机声场不错，佩戴舒适度也很好。
# 134.	入耳的那一刻惊了！买过最贵也是最好的耳机，听着古典绝对是最好最值的
# 135.	索尼a30感觉推不起来，，，，耳机真心不错
# 136.	非常不错 应该是便携式耳机里听交响最好的
# 137.	很棒，不过太吃控制力了。前端一定要控制力好
# 138.	听觉效果好，很喜欢。但塞在耳朵里时间长了不太舒服。
# 139.	耳机使用一段时间再来评价，音质很赞！不愧是旗舰耳机！
# 140.	宝贝收到了，很好的宝贝，音质很好.客服态度也非常好，物流很快，以后还会再光顾的，
# 141.	刚开始听非常非常失望，一段时间了，试一下阿姐鼓，还算可以。
# 142.	没有想想中的漂亮，的确很小，音质还不错，刚到手的神塞，还不错哦，到货速度超快，20个小时到了
# 143.	可以说是非常不错了，这个价位没什么好犹豫的了
# 144.	第一次在京东购物，东西很满意，没有付面的，昨天上午下单今天上午就收到，物流超快，70多的老汉第一次感受到京东带给的便利，同时也感受了京东的诚信，值得点赞赞赞赞。下次再见！
# 145.	已经听了很久了，很不错，退烧了，被媳妇骂得狗血淋头也值了
# 146.	非常满意，煲机中，期待之后的效果。
# 147.	低频下潜非常深，高音厚实，声场大。
# 148.	京东购买多年，不满意能退能换，放心购物，开心购物，延保服务真的很棒。。。。。
# 149.	还是很不错的，做工好，音质也好。声场大、解析高，听古典一流。
# 150.	音质因为没有煲开，所以高音还是毛刺，其他都很不错。好推很开阔。
# 151.	我特别喜欢的一款耳机?，素质特别高！等煲开后，追加评论！
# 152.	音质非常棒，大牌就是不同，绝对称得上顶尖技术，其它牌子真的没法比
# 153.	开机完美，煲机待续，音效很好
# 154.	东西很好，京东物流也是很快，第二天就到了。
# 155.	音质非常好，为了不买到假货，我只能来京东了！
# 156.	很好听！比z5小巧方便！z5要睡觉了?
# 157.	很好，回响，这回就不怕开视频没有声音了，哈哈哈
# 158.	正品，上午下单，下午就送到，超快！
# 159.	声场很大，低音很好，解析很棒！就是价格高了有点小心疼，哈哈。
# 160.	不错的耳朵，声音听起来很逼真
# 161.	绝对大师级的音质，与众不同的调音，非常喜欢。
# 162.	音质很好，比hd650差距不大，低音上感觉还要胜出。
# 163.	人声远。声场大。很美。
# 164.	体验了一天，声音在逐渐打开。很好。
# 165.	送货速度很快，耳朵质量很好，音质很不错，很喜欢。
# 166.	耳塞很轻，解析力高旗舰耳塞不?。
# 167.	效果大大出乎我的意料 太强悍了
# 168.	德国出品，携带方便，听音乐音质非常好。
# 169.	双十一，3788入手。耳机真的很强。小小的
# 170.	非常不错，不愧是德国品质，而且无论听多久都不会头疼！
# 171.	没想到听流行乐也相当给力，别看小，素质相当高，开声相当满意。资金到位的话，IE800。
# 172.	好东西，效果就是不一样，用过便爱上了，真心不错，喜欢
# 173.	森海塞尔（Sennheiser） IE800 入耳式HiFi耳机 旗舰声音很好，很享受!
# 174.	没有线夹，分线器的设计使得听诊器效应很明显，其他很好。
# 175.	经过一段时间的使作，效果得确不错，非常喜欢！
# 176.	东西不错，还没开始用，价格也很给力
# 177.	很不错的耳机，价格很合适
# 178.	音质超乎想象，无比震撼！
# 179.	做工一般 包装简陋 高音很吊 中音不错 低音很深
# 180.	音效真的太棒了。简直把耳朵宠坏。
# 181.	很赞的IE800，音质很好哦，哈哈。
# 182.	正品完美，双十一保价也很快，京东物料厉害。购物还是选京东最放心。再次给送货小哥一个赞?
# 183.	很好很给力，森海赛尔的耳机专业
# 184.	音质特别好，高端大气携带方便！
# 185.	顶级耳机啊，非常喜欢，希望能用满5年！
# 186.	好几年前就像买的 终于买到了 收到后感觉非常好 跟期待值相近赞一个
# 187.	非常好，与描述的一致，很值得购买
# 188.	好听，场很辽阔，效果挺震撼的，没失望
# 189.	可以，很好，性价比高！！！！会推荐给朋友！！
# 190.	总结三个字:非常好！物超所值！
# 191.	旗舰旗舰！买来感觉高大上，好像自己登上了旗舰
# 192.	很好 随便用用 但愿能用半年。
# 193.	耳机很不错，音质很好(?▽?)
# 194.	超级棒的耳机，不过要煲500小时才能发挥出全部功力
# 195.	虽然很贵但是非常好，完美无缺！！！！！
# 196.	听着听着突然好感动，很好。
# 197.	相当好评，编号也是五万以后的新品。
# 198.	不错，物流很快，耳机也还行
# 199.	和ie80差距一耳朵，3000多很值得
# 200.	一直喜欢终于下单了，煲的很好用了
# 201.	收货很快，试听了一下还不错！买来收藏了！
# 202.	音质很清晰 清脆 比我的ie80强太多了
# 203.	不错，老妈很喜欢呢，满意！！！满意！！！满意！！！
# 204.	东西很好，快递也很给力，非常满意
# 205.	IE800音效一流外观也很漂亮很清晰音乐就是入在耳上不是很稳定，
# 206.	非常满意的一次购物，客服服务非常好，给满分
# 207.	东西收到了，包装很好?听了一下效果也很好应付该是正品
# 208.	佩戴不怎么样 音质很好
# 209.	800还是很赞的 佩戴也很舒适 期待800s
# 210.	非常好的耳机，音质非常棒，喜欢。
# 211.	东西很不错，推荐，还会再次购买！
# 212.	非常棒的声音，不会后悔
# 213.	好用好用好用真的很好用的哦。
# 214.	非常好，希望配件多一些！
# 215.	很好，动圈的顶级耳塞
# 216.	煲机后才感觉耳机的声音真心讨人喜欢听后心情舒畅
# 217.	还待慢慢听，很喜欢这个小体积的塞子
# 218.	听感很强大，效果非常好！你值得拥有！
# 219.	声音非常清澈，解析好，听长时间耳朵不累
# 220.	物流很快，赞一个！音质等体验后再来评价
# 221.	小东西真神奇 太好听了 不愧耳机之王
# 222.	很好，是正品，秒杀所有听过的入耳。
# 223.	很好听，还没有煲出来，高频惊艳
# 224.	很好很好，音质真的是没的说，一级棒。
# 225.	一耳朵很惊艳，非常不错，继续煲煲试试
# 226.	听了一段时间，比IE80还是要好很多。
# 227.	非常喜欢，以后还会关顾的?
# 228.	音质很不错，相当适合听古典。
# 229.	不错，声场很大，感觉在听音乐会
# 230.	东西送的很快 效果还不错
# 231.	t土豪同事买的，拿过来看了看很好。
# 232.	很棒，很棒，非常愉快的一吃购物体验。开心?
# 233.	到货很快，正在煲，感觉不错！
# 234.	物流很快，送货服务态度很好，产品质量不错
# 235.	很快收到了，看起来不错
# 236.	有一耳朵的提升，非常棒
# 237.	效果很好，配合很不错，送货也很快
# 238.	给家人买的，买回来就用了，太好用了
# 239.	刚到货，还没拆封，速度很快
# 240.	好，很好，非常好….
# 241.	东西特别好，下次还在来买，谢谢你们
# 242.	东西很好。。。煲机中
# 243.	比80强太多了，一耳朵提升，很好的耳机
# 244.	很好，京东自营的商品还是靠的住
# 245.	物流很快包装一般，一耳朵惊喜
# 246.	果然很震撼！这价格也是没谁了！果断剁手！
# 247.	低音非常给力！高音也不错。最爱~
# 248.	父亲很喜欢，下次再来，非常棒！
# 249.	退烧了，大爱。配合黑砖完美。
# 250.	感觉和原来的耳机相比有很大的提升。
# 251.	很好的耳机，比ie80要强的太多了！
# 252.	发货快，配送快，很不错，一耳朵就懂
# 253.	很轻，隔音说得过去，配带舒服。
# 254.	效果不错，物流很快，配送态度好。
# 255.	包装很好，服务很好，东东等煲机后再评价
# 256.	感觉不错，价格也很公道，值的购买！
# 257.	正宗德国产的耳机，非常好。
# 258.	商品和商场的一样，京东的快递也太快了！
# 259.	非常好 真的 期盼已久的耳机
# 260.	质量超好！音质超棒！！点一百个赞！
# 261.	很不错的耳机，但是需要好的前端
# 262.	感觉很好哦<br />不后悔，高大上
# 263.	听音乐很好，又买的SONY播放器
# 264.	很棒的耳机，音质很好
# 265.	hao，真心不错，一直在回购的
# 266.	速度非常快，省时省力。都很喜欢。
# 267.	不错，用的不错，很好用哦
# 268.	物流很快，东西还没用，用过后再来评价
# 269.	非常好，下次再买！买！买！
# 270.	使用过最好的，真心不错，呵呵、
# 271.	佩戴非常糟糕音质还行
# 272.	一分价钱一分货啦，耳机很不错的。
# 273.	已经煲开了，声场非常开阔，值得拥有
# 274.	很不错，音效也非常好。
# 275.	很不错的耳塞   很喜欢.
# 276.	产品非常好，京东非常棒
# 277.	收音机煲机，机子很不错！
# 278.	音质超好，快递速度很快
# 279.	太牛了好产品。喜欢喜欢
# 280.	非常好，配上d100绝配了
# 281.	800解析比80好很多 一耳朵差别
# 282.	正品无疑~音质很棒~待煲
# 283.	好棒的一款耳机，很喜欢
# 284.	解析度不错 很精致小巧
# 285.	很棒的耳塞 值得拥有
# 286.	效果很好，双11划算
# 287.	效果很不错，但是价格也很高！
# 288.	发货速度快，包装的很好！推荐购买
# 289.	非常满意，快递师傅非常负责
# 290.	森海的新旗舰还是很不错的
# 291.	帮朋友买的，他很喜欢！
# 292.	降价一千多的时候买的，非常划算
# 293.	还是很不错的 很喜欢 很喜欢
# 294.	开声秒80 很强势！！
# 295.	声音很纯正，听着舒服
# 296.	音质不错，很好。。。。。
# 297.	非常好，顶级品牌不是吹的
# 298.	效果确实很好，值回票价
# 299.	很好的东东，值得推荐，京东不错！
# 300.	很好，正品，发货速度快。
# 301.	效果很好不错很好！！！
# 302.	东西很不错，值得购买！
# 303.	东西不错，物流很快！
# 304.	德国鬼子耳塞还是很强的，这么小的耳塞可以达到如此高度的惊人素质，刚上市那会儿就想买了，6000多没下手，这次一看只要3000出头了赶紧下手啦，圆了一个梦。好了评价一下，佩戴挺舒服，并没有很容易掉出来或者太小不舒服等，我觉得倒是挺舒服的，耳机盒很精致，设计也有小心机啊。刚开始煲了大概30小时吧，用爱疯直推感觉中频的人声有点沙沙的有点远，高低频都很棒。用dx100推感觉很合适，各方面挺均衡。用桌面耳放好像并不合适，低阻高敏可能最适合hifi播放器po直推，耳放放大了底躁有点大。其余方面所有都很好，开声比ie80好很多啊#，果然是一分价钱一分货。好评！
# 305.	好到爆炸 一个动圈单元 声音细腻程度堪比动铁，一个耳塞居然有耳机的声场，看上好几年了，降价就买了。实现梦想啊 哈哈哈哈
# 306.	终于到了，从上海发货，一天就到，比其他快递快，五星好评。IE800比我原来的IE60一耳朵提升，解析力强了不少，高频有点刺，估计是没煲开，用几天估计会好很多。
# 307.	好东西到手。我也就是凑个热闹。第一次买HiFi耳机，我都没有前端和耳放。手机推的。可能有点暴殄天物。PS.耳机真不错，钱不白花
# 308.	验证为正品，开箱黑砖初煲了两个小时，入耳就惊艳到了，比IE80提升不止一耳朵。听诊器效果也是杠杠的，好吧，这是提醒我要静静倾听音乐的塞子。
# 309.	特价收的，不错，原封的，特意又作了一条4.4平衡线，不错，现在akg3003，索尼ex1000,舒尔846,ie800,还是要换4.4的,过几天再作一条1000的4.4平衡线的
# 310.	手机直推音质也很不错，比一般的耳机好很多，音质解析清晰，低音弹性十足，三频很均衡，唯一我觉得不好的地方就是佩戴，两段线接口的位置比较重，耳塞容易往外掉，不知道为啥这样设计，其他都挺好的
# 311.	音质完美，声音清细明亮。就是带不稳，容易从耳朵上脱落，所以我改了个博士的耳塞胶，这样就好多了！
# 312.	去年双十一买了一个IE80，听了一年感觉很不错，今年就想着再换一个IE800听，终于在双十一活动期间下手了！我先说说购买体验吧，这次的京东物流，说实话有点让人不太满意，这好歹原价也是个将近5000块钱的东西，包装跟平时的其他小东西一样很随便，外面就简单套了一个塑料袋封上，连多加一个纸盒，里面放点泡沫纸之类的都舍不得，等我收到打开看的时候，耳机包装盒都有些许磕变形了，而且背面的防伪码看上去也磨得有点模糊陈旧，给人第一感觉就好像是买了个水货似的，毕竟现在800水货比较多，但是平时在京东的一些旗舰店也经常买东西，还是选择相信京东旗舰店，然后通过电话和网站分别查了一下防伪码，也确实是正品，没有问题！但是包装是真的随意，便宜的东西也就算了，这种东西包装得这么随意很容易给人一种买到水货的错觉……<br />其次，我再说下耳机本身吧，森海的品质确实值得信赖！一分钱一分货，物有所值！耳机的颜值、品质和做工都对得起这个价格，陶瓷外壳很漂亮，体积也很小，至少比我去年买的80在体积上明显要小一些，但是上手的感觉却明显比体积更大的80还要略重一点，线材明显也比一般耳机好很多，包括两千多的IE80，从这些方面来说都很满意
# 313.	最后再简单补充一下耳机听感方面的吧！关于听诊器效应有略微那么一点点，可以说忽略不计吧，相较于80来说，有很明显的区别，就好比线材一样！刚一听的时候很糊很闷，而且不管是听纯音乐也好还是人声歌曲也罢，总之就是一个字，糊、闷！就跟路边摊没有区别，甚至还赶不上，纯音乐要声场没声场，要解析也没有，但是听了一天以后就会发现，诶，不错，有点意思了！估摸着也就是10个小时吧，这个时候基本就算是勉强开声了，没有初听的那个糊和闷了，纯音乐的声场上来了，听人声也不那么闷了，吉他类的歌曲或者曲子，解析开始明显感觉得到了！确实不愧为动圈之王！相当满意！下一步打算物色一个前端，希望后面会有更好更出色的表现！
# 314.	在顺电试听过80s和800,当时觉得80s佩戴舒适一点且声音软一点温暖一点，主观上偏向买80s。不知什么心态回来买了800。800一耳朵声音紧，硬帮帮，声场大，解释好，乐器定位清晰，但声音没有感动到我……
# 315.	京东物流一如既往的给力，同时收到机器和耳塞，第一次试了一下感觉还没我的airport好听，也不知道怎么分辨真假，瞬间没了兴趣，可能要吃灰了
# 316.	盒子之前被开过，盒子的码验证没问题，默认正品，901s开声高音毛刺感强烈，声场大于jvc fxz200 细节更多 我是杂食者 欧美流行听着很爽快，虽然有点刺得慌。继续煲机，看看会有啥变化。还是默认好评吧。
# 317.	还是喜欢森海的味道，说实话做工比ie8好很多了，陶瓷外壳的机体设计挺不错的，不过比较容易留下指纹。皮质的便携包感觉很高大上哈！平时比较喜欢古典和大编制电影原声，IE800在这方面和乐器演奏上的表现力太好了，解析力依旧不错，再加上独特腔体的设计，超宽的频响仍是森海令人印象深刻的地方。可能是个人原因，感觉中频有点儿过于饱满，希望煲过或者搭配合适前端后调整一下！期待煲后它所带来的震撼！
# 318.	音质没的说，听感也不错。有4.4平衡线好评，但是线材质量和做工真对不起旗舰这两个字。
# 319.	快停产了，买了收藏的。记得几年前买的好像没有小金标？解析一如既往，低音确实比以前残了。至于听诊器效应换个合适的耳套，用夹子夹住，基本可以消除很多。毕竟夏天戴这个不用绕耳，比较方便。
# 320.	刚入手，需要煲机，声音表现待以后追评。外包装精致简练，不拖泥带水，让人喜欢。附赠的皮壳便于收纳携带。机器实际比商品页面中照片展示的要小一些，黑色陶瓷机身在光线下熠熠生辉，整体感觉时尚大方。机线很有质感，连接口设计得体贴心。德国制造。很久没有发照片晒单了，刚好手头有号称地表拍照最强手机：华为p20pro，于是此次就用它拍照晒一下，不过IE800也配得起这个手机。
# 321.	等了很久，昨天还忍不住下单了。这耳机三年前在香港音响展用华为手机m7听过，为此在头条写过一篇颇长的听后感。今天收到后简单用华为手机m9试听一下，喜欢的感觉没变，高音低音尤为凸出，最好适合出差长途交通工具上听交响协奏曲等大编的古典音乐。当然听歌也好，总觉得中音暗了那么一丁点，尤其听流行音乐欠点人声，个人认为westone W60要舒服点。<br />今晚回去用SONY黑砖推，我想效果更佳
# 322.	戴在耳朵上了，就不拍照了，哈哈！<br />声场大，低频有量优质，人声稍薄，其他方面非常满意，塞子可以退烧了，哈哈?
# 323.	双十一想来想去，没什么需要买的，但还想犒劳犒劳自己。一直对音乐情有独钟的我就决定更新一下耳机。之前经历了Cx310，IE60，这次就选了IE800。配上ZX100对我来说听着已经足够的细腻和流畅，按下播放键那一刻能够打动我这就值了。简单的包装风格也挺让人喜欢。
# 324.	耳朵收货，声场比较大，声音密度很足，低频下潜非常给力，声音细节还原性很好，也没有什么齿音，也就是说这款耳机是消齿音的，总体比较满意！绕耳佩戴也不错，听诊器效应@减缓了?唯一不足之处就是我的前端不太好因为我用的是金菊花回头借个金砖再试试吧
# 325.	隔日达的速度是令人放心的。早晨下单，下班前就到了。赶得上试用。配合刚到的索尼d100试听了一下，还不错的吧。熟了应该会更好。小东西大能量。好评了。
# 326.	昨天收到的IE800，马上开箱听，低频多，个人感觉比IE80多，解析和IE80差不多，应该过段时间会更好，在这种视野宽广的地方听大编制古典那种感觉真爽，京东秒杀3869拿下相思已久的IE800，就是线有点短，收纳盒没有IE80的安逸，其他都不很好，期待煲熟的感觉，好评！
# 327.	几年前就买了846，一直听到现在。感觉IE800的声场比Shure 846宽，听缓和的音乐感觉更放松。第二个优点是比846轻很多，带着方便。以后这个就是主力耳机了。
# 328.	声音方面表示可以，手机直推比苹果自带小白塞好，其实没可比性，但这耳机就是用来坐地铁公交用的，免声音污染。
# 329.	ie800和k3003，一个听感向，一个素质向。ie800虽然声场优秀，低频弹性下潜都不错，但解析，动态，人声却都不是很好。ie800的10khz以后的极高频比较丰满，所以听起来很透亮，很清澈，就显得解析很好，但实际上出来的东西还是少，少k3003一截。k3003低频量少，下潜还是可以的，弹性也不错，声场可能略差ie800但其他还是可以压ie800的，尤其是动态，k3003动态是很强的，就是一个交响塞。但k3003调音不行。ie800动态真心只能算一般，算不上好的。但ie800听感很棒，调音不错
# 330.	不错不错。新耳机没煲，低潜不足，高频刺耳。希望煲开了有最好的体验。求推荐个前端……
# 331.	ie800果然不错啊，首先低音很足，下潜很深，听纯音古典效果最好，其实人声也很不错，人的喘息声和换气听的很清楚，人声感觉离自己很近的感觉，我有一个pxc550，那个人声更宽阔一些，音质上是完美的，图片离有一个我到森海注册耳机的图，注册后会发来一个邮件，可以保证是新品正品没错，但是不满意的是包装，太烂了，盒子都磕破了，外边只包一个袋子，刚回来我还以为又是二手的，还有就是京东的次日达也没有完成，所以就四星了
# 332.	一直在关注，京东这次优惠力度不错，搞了次抢购，最终三零五九剁的手，编号52开头，跟我换过线的IE80相比，解析度确实比80高，声场也大了，期待煲开后的效果。
# 333.	收到货后插在ipad上听了下，还不错。因为还没煲开，人声听上去有点糊，但耳机灵敏度不错，对其低音更是满意。听了一组曲，觉得耳机适用于听带有节奏感的pop, r&amp;b,小型乐器演奏特别是对鼓乐的还原惊艳。
# 334.	这是手上最好听的耳机，之前一直用IE80，买80和800看中的是阻抗低（16欧）好推。800的低音确实好过80，一分钱一分货。800听试音碟中的直升机螺旋桨声音很清晰，80则有点散。听试音碟时25Hz信号要增加点音量可清晰听到，31Hz正常可听。听感是和自身的耳朵和喜好有关，一般的年青人（受过训练的除外）能听到16KHz左右的声音，年纪大的人只能听到12KHz左右的声音。800指标写的频响是5Hz~46kHz，不讲声压只讲频响没什么意义。总体评价这款耳机低音浑厚有力，中音圆润人声靠后，高音清澈透明。解析度比80好多了。
# 335.	京东包装一如既往让人无语。<br />身边没有砖头，所以直接先用nex感受了一下，<br />开声挺不错的，期待煲好以后的表现！
# 336.	ie800的收纳盒就不能学学拜亚的榭兰图吗。。感觉用这个收纳盒容易弄坏耳机啊。ie800分线的地方你缠绕后正好在收纳盒里面方块的圆脚边，要绕紧才能转弯。求问有没有类似榭兰图的收纳盒设计的ie800收纳盒，某b上找半天没找到。
# 337.	很小巧的耳机，单独来看很难与顶级联系起来，目前音质还不错，确实不太好推，同等音量调节下比EX1000声音小不少。期待更好的声音。
# 338.	感觉还不错，包装有一点小伤。耳机效果棒棒的，相信煲一段时间应该会更好
# 339.	耳塞罩确实容易掉，你们呢？有没有什么好办法解决呢
# 340.	还可以之前入手ie80，双11入手gr10e，感觉800没有gr10e女声好，乐器还是800，好，用一段在说v讨论370951822，双11入2条
# 341.	一份价钱一份货，音质比我以前的要好，还需要煲机，期待煲机后的音效。
# 342.	看着还不错的样子。用了这个vivox20 是听不出来什么，需要一个好的前端。毕竟是HiFi的旗舰。表现还是不错的
# 343.	价格不错。第二条IE800，三年多了，已经到了近50000号了，当年第一条是1000多……声音也有变化，新老各有特色，就这样吧。
# 344.	618终于降到5K以下了，果断下单。刚收到耳机，迫不及待的试听了一下。用小耳套戴着很合适，隔音好、不掉，最担心的问题没有了，从来戴不稳的K3003可以退休了。声音一开声还行，过一段时间再评价。
# 345.	经典耳机，需要煲机。初步听，感觉解析不错。看煲机后效果如何。
# 346.	IE800多年的愿望终于得到了 耳机中的奢侈品就是不一样 音质各方面都是相当好的 没有好的前段还是不行 手机听的根本不行 音量要开好大才推的上去 我自己之前在用IE80配手机还是很不错的 用IE800配手机还是别糟蹋自己的钱了 我就分享到这 希望你们采纳！
# 347.	只能说对比IE 80强得不止一两点，完全是在音绕，音绕，音绕耳朵不能自拔的感受，加上用个好前端推得干干净净的，真是不枉这个价格，4669入手，参考下。
# 348.	真品无误，开机听了效果蛮好，不像网上说的那么闷，人声也不算远，听钢琴很有质感，不过确实欠煲，音场没有想象中广，正在努力煲机中，期待后面的效果！
# 349.	送货速度快，但包装也太随便了。。。就一个塑料袋，盒子两角都有点压到了。防伪码查过，是正品。800的音质不需要担心，冲着三频均衡个它的声场买的，马上进入煲机模式。。
# 350.	初开声，用我的华为P10，音量控制在百分之五十以下，没有多大感觉。听了两三首歌以后加大音量到百分之七十多，感觉比我用过的I80，I80s感觉更干净，清澈，通透！
# 351.	入耳戴不稳，目前还在煲机中，便携包上有刮痕。外观很喜欢。快递包装不行
# 352.	听了有几天了，感觉不错，听流行歌曲比起ie80好了很多，不像ie80人声那么靠后，再听一段时间会更好的吧！
# 353.	刚开始听有点闷，十来天后好了些，感觉跟我原来的ie80听感不大相同。后者有一种磨砂感，800好像没了这种感觉。其他方面，低音确实很不错，弹性很足，下潜够深，听打击类乐器比如鼓乐很是带感，高音也有点接近k3，解析不错；但中频听流行人声总感觉不够厚实。人无完人，机无完机。还有，外形做得太小，完全没必要。稍微大点拿起来才更合手
# 354.	听了几天，音质还是对得起这个价的。
# 355.	初烧入个ie800，感觉还不错，慢慢煲着吧。听acg比较多，但是脑子发热就买了ie800。等过段时间入个女毒基本就差不多了。不过这颜值真的高，好看就完事儿了呗?
# 356.	初烧的我，苹果直推，感觉细节比其他耳机多了很多，煲一段时间上个Pha3看看有什么惊喜。音源影响很明显，很多以前的音源不能听了，Apple music 音源还可以，其他的流媒体平台有区别啊。
# 357.	正品保障！耳机初体会，三频均衡，低音量足不轰头。解析力惊人，细节表现深刻！
# 358.	这款耳机最能体现或者发挥它的特点就是听交响乐！当然流行人声更不在话下
# 359.	我用过最好的耳机，入耳舒服，带久了也不会痛，用来听无损音乐，人声清晰，声场广阔，不愧森海塞尔一代神器！
# 360.	一直用IE80，信赖森海。受ie800毒深，心头痒痒难耐，赶上618促销，果断出手。煲机中，以后再评。
# 361.	今天刚收到货，京东发海外10天左右还是很满意的。很久没买森海了，刚开箱发现没有塑封、包装盒有划痕还以为买到二手了，官网防伪查了下是正品。声音不评价，网上测评都有。总体很满意。
# 362.	低频量很足 还算比较耐听 佩戴舒适度 比某些大耳好 至少不会夹头
# 363.	用了1个月了，声音出来了一不错，特别是高低音。中音也不错，不愧是旗舰耳机！
# 364.	以前就很喜欢这款耳塞，还经常去实体店蹭听，无奈价格一直居高不下～现在价格已经趋于稳定，我便决定入手。收到货后已检查，是未开封的正品行货；包装比较简单，配件也不算丰富，但都算是比较贴心实用；上前端开听，和以前试听感受基本是一致，只不过因为是新耳机，还需煲机性能和听感才能达到理想状态。简单说说我的感受吧，极小的单元尺寸下，却拥有宽广而规整声场，优良的动态反馈；高音亮而顺滑，低频有质有感层次分明；中频人声也在可以接受的范围内，纤细偏薄有力量，结像位置稍远了点。总体而言，更适合器乐、女声、ACG、大小编制等。另外，虽然标示阻抗只有16Ω，但灵敏度也只有103dB/mV，换算过来就是121dB/Vrms@1kHz；这个数值在同类竞品中并不算高(黑黄鹂132dB/Vrms@1kHz、榭兰图128dB/Vrms@1kHz、SE846134dB/Vrms@1kHz)，再加上森海家的超宽频微动圈不太好驱动～所以，尽量选用输出电平较高或大电流输出的前端设备(大部分iphone和VivoXplay的输出电平挺高的，至于便携DAP和台机就更不在话下)，这样可以获得更好的音质。其它方面，使用一段时间后再说
# 365.	比IE80好多了，#，一分价钱一分货，赶上618活动弄一条满足自己的耳朵?。
# 366.	这是在京东买的第二个ie800了，真心不错，可惜上一个用了将近一年多了，都煲好了，却让陌生人给牵走了。这一个来了后一侧封条有点开胶，没敢打开，要求换货。京东客服挺好，立即就给安排换了。打开后一听就是ie800的声音，信赖京东。
# 367.	手头有IE80。但是看到IE800现在的价格，实在忍无可忍，剁手！除了听诊器效应，无论音质还是佩戴的舒适度都没得说，好！
# 368.	还可以，没有一耳朵的惊喜，应该要保一段时间。后面有提升后再来追评。
# 369.	在K3000I，Z5，IE800之间纠结了很久，最后还是就定了IE800，说句老实话，平时听音乐?还是已流行歌曲为主，所以在选择上个人更倾向Z5，但是考虑到耳机的解析力和三频的表现能力，最后还是选择了IE800。刚拿到手的时候感觉真的好小，而且耳机使用的内置发声源是钕磁石，所以存在磁场，感觉和路边摊没有什么区别，但是当你听了它的声音，你就能明白到底值不值这个价，听下来感觉真的很好，可以听到很多细节，个人觉得三频的表现也很出色，它有一副好耳机应有的基础。
# 370.	虽然数字上看挺好推，但用手机直推还是吃力，低音闷高音刺，换了国砖好很多！煲一下看看吧。
# 371.	第二次购买了，给家人买的，价格优惠。一经使用，听音乐只能用这个了，别的耳机实在不想再用了，一分钱一分货。清晰明亮，物有所值。
# 372.	东西很喜欢，就是线看起来太脆弱了，刚开始听了一会，感觉还没有出来，期待后面完全煲来了的感觉。
# 373.	挺不错的物品，躺床上可以听东西了，比大耳罩子好翻身。配合世界第一播放器老好听了ヘ(￣ω￣ヘ)?
# 374.	早就种草了，这次趁618大削价入手。小心耳机居然声场很大，满意！包装有点简陋。
# 375.	查了一下，是正品。初煲中，刚出声感觉还不如之前的8i，过段时间再听听
# 376.	还在煲，配个前段吧，包装就是满满的山寨感觉，验证过了是正品，凑合吧
# 377.	音质比ie8有提示，配戴确实不友好。好在我的窝家党不外出听歌。吐槽一下外包装如图
# 378.	ie800配Mojo，Mojo还好，ie800确实与众不同，感觉比se535给力！
# 379.	还再煲机中，希望能有所提升。京东物流很给力，广州附近有仓就是快啊。先不说了，泡面?好了。
# 380.	真棒，喜欢这种声音，本来还想着入手800S的，还是喜欢800
# 381.	开箱前检查真伪没问题，开声不如手里的榭蓝图，慢慢煲吧。声场还不错，挺满意的，前段dx200+卡7。
# 382.	刚拿到手试听一下，果然不错小小的体积竟然能彭发出震撼的效果。期待以后会更好。
# 383.	东西音质不错。解析度高，声场很广。但是还未达到自己预期。购买一个月。欲出～15693608811
# 384.	嗯～真香～比榭兰图通透，榭兰图对流行还是有点妥协的。IE800几乎就是正宗的森海味了。800s价格是800的一倍了 现在入手正合适。
# 385.	感觉还不错，老旗舰早年种草现在好价除草。还是动圈好，技术革新不会使得老塞子失去意义。
# 386.	开机听就会感觉挺舒服、自然，煲机后太爽了，值得拥有；网上评论k3003比这款好，两款我都在听，k3通透，综合还是喜欢ie800多一些，听着温暖、舒服、自然些
# 387.	声海的声音确实值得赞 就是那传说中的德国制造真的没话说了  假如真的是纯手工制作的话那就好了 六一八活动价格真给力 不错。。。。。包装啥封条都没有。。不过京东自营店的品质还是信得过的。。
# 388.	很不错，除了人声，差不多能把以前用的ckr100吊打
# 389.	旗舰机效果确实好，三频均衡，不过效果最好的还是交响乐！
# 390.	试机中，开声还行，煲机看看，效果后续评价了
# 391.	耳朵不好使 听不出来啥   但是质量挺好
# 392.	还好，感觉比IE80好一点点，果然是一分钱一分货，十分钱两分货，越好的耳机，花的钱能提升的量真的不多了
# 393.	听感挺不错的，乐器方面层次感很强！但是人声确实不出众！
# 394.	耳机是正品，刚听的时候，发出来的声真叫一个酸爽。。煲机3天后好多了。蔡琴的渡口听了3天
# 395.	现在使用感觉还可以，玩吃鸡，听到的脚步比较清晰。对上段位有一定帮助！
# 396.	宝贝终于到手，打开一看所有东西整齐摆放可以肯定是一手原装货。旗舰货就是好，包装和外表都比手上的ie60好太多了。一直听周围朋友说这塞子怎么好怎么好，所以趁京东双十一优惠力度大剁手赶紧入了一条。一下子从ie60提升到ie800估计是满耳朵的提升。下一步就等入个好前端了。说下这么贵的东西京东就一个胶袋包装也不怕压坏了。快递小哥给力度摸黑送货上门估计饭也没吃。赞一个。
# 397.	初听耳朵受不了 ，越听声音越好 ，不错   要配耳机线夹才行
# 398.	正品，而且音质真的好听，比我的人妻b一耳朵就听出来了，一个小小的耳塞居然这么好听！颠覆了我的世界！
# 399.	这个耳机真不错！关键轻巧戴起来舒服简单，就这点就喜欢啊！比什么绕耳的，戴起来还得看看是左还是右的简单多了
# 400.	效果不错，带上几乎听不见别人讲话了都，别家卖的虽然便宜不少但真不敢买啊，这个绝对是正品。赞?
# 401.	不会夹耳朵<br />耳机不错<br />麦也很清晰<br />音质不错<br />隔音效果好<br />外观不错<br />低音不错<br />帮朋友买<br />声音不错<br />自定义<br />
# 402.	说实话开声还是挺难听的，感觉这款耳机声音太薄了，解析力还是可以的吧，细节表现很不错，各种乐器也比较有层次感，再听几个月试试
# 403.	隔音效果好，但一耳朵的感觉没有IE80惊艳。但三频确实均衡，是个好塞。人声比较靠前，比IE80的乐器声抢镜要好。感觉跟之前的K3003差不多吧，不排除是我前端没有推好。下次去蹭个耳放试试看
# 404.	使用了几天，总体声音不错，人声稍显不足。待换一个前端再听。
# 405.	IE800,完美音质，耳屎都听出来了，可惜没什么折扣。盒子外观好像放了很久的样子。
# 406.	经典，8848推的，效果赞的一逼，物流给力，自营店价格比海外代购价格高，但是买的是放心，正宗原装。给力
# 407.	配送很快，满分。耳塞容易掉出来，耳机线太短，舒适度没有威士顿好，手机直推效果一般，目前是c4，骑车的时候听的多，爬山走路的时候也会听，再看吧……
# 408.	耳机不错，效果不一般，样子也好看。就是同时购买的煲机服务不知道怎么回事。
# 409.	京东包装一如既往让人无语。<br />身边没有砖头，所以直接先用nex感受了一下，<br />开声挺不错的，期待煲好以后的表现！
# 410.	ie800的收纳盒就不能学学拜亚的榭兰图吗。。感觉用这个收纳盒容易弄坏耳机啊。ie800分线的地方你缠绕后正好在收纳盒里面方块的圆脚边，要绕紧才能转弯。求问有没有类似榭兰图的收纳盒设计的ie800收纳盒，某b上找半天没找到。
# 411.	京东自营送货速度很快，昨天下午下单今天上午就到了。盒子没有磕碰。接口做工确实差点，开声还可以目前正在煲机！没刮防伪码不知道是不是正品！
# 412.	外观小巧、精致，声音素质高，齿音控制不错，更多的效果还要等煲过一段时间再看了
# 413.	初听，各方面素质都比手里的ie80s强，正在煲音中，待煲后听感
# 414.	一直用森海塞尔CX880，换了这个也没感觉有多大提升，等煲开了也许会好点儿
# 415.	声音棒 顶级耳塞 古典一流 塞子可以退烧了 准备入大耳箱子
# 416.	买了这款，3003，SE846就收集齐了，各有特点，IE800是唯一的动圈，很喜欢这种声音，就是听诊效应比较严重，适合在家里坐在那里安静的欣赏音乐。
# 417.	京东物流是真快，中午拍的晚上就到了！估计是没煲开的原因，高频有点刺，华语女声齿音重，素质还是对得起这个价格！等煲200小时再说！
# 418.	ie800的声场真的是可以 这么小的腔体 但是低频确实在控制力不好的时候 散混多 还是需要一个好的前端
# 419.	刚开始煲机，开音不错比80强。继续应该越来越好
# 420.	一直想要的，几个合适入手。音质完美。
# 421.	需要煲，佩戴没那么不堪，我带着蛮稳蛮合适的，一个线夹就能解决听诊器问题，还不错，比之前的踢飞10舒适不少
# 422.	发现这货用ipc50%音量就能推动，iPhone5S稍微高一点55到60%就能推得很好。效果没得说，但还需要煲一下的。在MacBook Pro上用三格音量就能推得很好。
# 423.	包装完好，耳机检视完美，官网验证是真货。试听音质清晰，不是音响发烧友，但也感觉舒服，干净清脆。
# 424.	第六个森海塞尔的塞子了，从700 到1000多到2000多再到现在的IE800，一直是森海的铁粉儿！
# 425.	还不错，趁有活动果断下单了，就看京东什么时候上SE846了
# 426.	木耳，配了黑砖听，还行吧，比游戏耳机听着舒服是真的
# 427.	音质可以，的确乐器比人声好，作为耳塞并不好推，不推荐手机用户
# 428.	耳机是不错。可惜买来就降价，申请了报价。还不错。不愧是森海的产品，还是一如既往的喜欢。
# 429.	做工，品质，音质，的确不错，就是蛮贵，超喜爱
# 430.	800,必须要上耳放，K3003可以用iPhone 直推。所以800合适在家听音乐，k3003合适听歌曲和网络广播和户外随身携带方便。
# 431.	800的低音非常好，象配了低音炮。K3003的高音非常清澈、纯粹值得点赞。两个耳机的特点都非常明显。
# 432.	以前用80，这个是女朋友买的。有女朋友加成，很棒的耳机！  唯一缺陷就是二手
# 433.	5千元内算是比较合理的价格，与榭兰图比较各有特点，都是旗舰级入耳，相信京东自营。
# 434.	煲到差不多才来写评论，虽然说确实好听，但是价格也确实不便宜……
# 435.	完好包装，开声有点惊喜，好轻巧的塞子。煲机中
# 436.	全新、小巧、精致，说ie800人声不好的都是扯淡，我觉得比k3k3好听，声场定位比k3k3自然，只是在高音华丽和空气感略逊一筹
# 437.	森海的品牌一直是高品质的代名词，用了好几款森海的耳机了，耳朵越老越挑剔。
# 438.	不愧是森海的旗舰，一开声就注定不凡！比我的索家N3AP+平衡线的音质还要好，值了！
# 439.	刚拿来就试听了，音质挺好，相比ie80,通透了不少。
# 440.	算是退烧了吧，前前后后买了很多耳机，最终还是选择了森海，喜欢森海的声音。。
# 441.	整体效果不错,正在煲机,煲完后再评,耳塞戴上后容易脱落
# 442.	大赞，听感爆棚，人声靠后，煲机走起。
# 443.	比我之前的ie80好了不少，完胜，全面的大气和游刃有余。一定要戴次小号耳塞+大力插入，其它耳塞对小耳洞来说声音跑偏很多
# 444.	我是初烧，能对比的就是qc25耳机，音色层次感分明，入声动耳。没煲开的情况下有这样的声音很满意！
# 445.	跟k3比还是有所不同的，坐等周末拜耳动力榭兰图送货，到时再对比下?
# 446.	试了一下，感觉不错，相信煲过后会尽展王者风范！！
# 447.	过年活动下手了，听了一段时间感觉挺好的。比我以前的80好。
# 448.	产品不错，服务也不错，第一次京东购物，感觉不错！
# 449.	买了 细节比sony z1k 强 这几天好好的煲下 过段时间再来补充
# 450.	耳塞解析力很高，低音下潜到位，高音部略有些刺耳，多推一段时间希望变好，主要使用C4出街用。
# 451.	刚买来听真是渣，煲了半个多月后，完全不一样，耳塞中的战斗机，不错，挺好，京东自营就是好，
# 452.	不错不错。高频，顺滑。低频 弹性十足
# 453.	耳机效果不错，解析度高，层次分明，听交响乐有如亲临现场。还需煲机。
# 454.	包装略显简单，使用初始，品质待考证！
# 455.	旗舰不多说了，一开声，就比IE80好，现在煲机中~提升细节~
# 456.	音质比一般耳机强好多，值不值这个价就不清楚了。买了就买了，多听多用
# 457.	初听感觉还可以，期待煲后的音质。没有好前段，先用手机听听……?
# 458.	还不错，容易脱落是硬伤呀，有想要的吗？3999转手。刚入手。
# 459.	正在煲，开声金属味浓，越煲越润，低音下探深度不错，解析得当
# 460.	木耳啊木耳，摔。。。。还在煲，不过越来越动听了
# 461.	不错，音质满意，比ie8i素质高，不愧是旗舰，煲一百小时先
# 462.	还可以，用来听岳云鹏相声觉得不错
# 463.	包装完好，两种方法验证是正品，音质初听是深海味，高音有点刺，开始煲机之路。
# 464.	刚开始有齿音，煲了一段时间有改善，低频控制很好，高频亮。
# 465.	包装盒有点破损，里面包装挺寒酸的。没关系了，主要耳机好就行了，已经查了是正品，正在煲机中。
# 466.	降价用券 价格还是很不错的 听听看 值不值还不能立即说
# 467.	IE800，已经听了30多个小时，目前效果满意，希望以后会有惊喜。性价比不懂。
# 468.	惊艳的音色，比我之前的solo3和N30好的不止一个档次
# 469.	声音还可以，心水很久了，趁618活动拿下！
# 470.	这个塞子等了很久 正好有货秒了 整体不错就是听诊器严重 适合安安静静的在家听
# 471.	听了几天了，感觉效果提升了不少。适合听乐器
# 472.	挺好的，有了这个，以后就不用买别的了，先煲着吧。
# 473.	马上试听了一下，可以，够用！
# 474.	东西是正品，声音值这个价钱，活动3x49到手划算的一比
# 475.	旗舰型号，没得说，音质满意
# 476.	还行，可能要用一段时间，看外观好像不太结实比较脆弱，相信京东的质量。
# 477.	好马还是要配好鞍，这套下来基本可以暂时退烧了。
# 478.	耳机还不错但这不像是一款三千多耳机的包装啊
# 479.	初听和之前用的700多森海差不多，但塞子很小巧，戴着舒服
# 480.	刚到手，耳机比较平衡，是森海的感觉，真在体验
# 481.	很好值这个价，刚出声效果就比我煲了一千小时的金涡轮还好。耳机很小巧佩戴也还行，如果配件里送个夹线就好了能很好解决听诊器效应。 唯一的吐槽就是森海真是越搞越小气了，送的配件才四副套子一根棒棒，原装套子感觉就是个山寨产品没点质感，还得劳神去配几个合适的记忆海绵套子
# 482.	新耳素质也还行，低音不澎湃。先煲煲再说
# 483.	声音很好，就是要求播放器太高端了。
# 484.	不愧是古典之王，气势磅礴，音浪澎湃……佩戴还挺舒服的
# 485.	不错，S没有货，只能选择这个了。
# 486.	正在使用，感觉不错。我希望有更多好产品。使用一段时间再来说说
# 487.	一耳朵就超过ie80，煲开不知道啥感觉，手机推感觉还行，推力不够些
# 488.	梦想中的耳机，现在价格比较实惠了，人生中第一个耳机就是森海，犒劳下辛苦的自己
# 489.	尺寸比我想象中的要小 音质没得说 必须好评
# 490.	这个烧算是发到头了 耳机音色挺棒啦，陶瓷的东西不知道扛不扛摔
# 491.	其他都还好，佩戴不舒适，听诊器一样
# 492.	从一百多的耳塞到五千多的耳塞都玩过了，动圈之王，帅帅帅！！！！
# 493.	音质煲过后还不错，继续煲机中
# 494.	包装有磨损，查询为正品
# 495.	对的起定位，声音清晰，耳感舒服。价格偏贵。
# 496.	买东西一直来京东，质量有保证，价格还便宜！#不错。
# 497.	森海塞尔大厂作品，还是值得购买的。动圈是越听越有味道?！
# 498.	小巧漂亮，佩戴舒适，携带方便，音质不错！
# 499.	气势恢宏，音色优美！壮哉我大800
# 500.	降噪效果不错，在单位听歌同事说话都听不见，可以专心工作。
# 501.	物有所值，降噪效果好，音效等我听一段时间之后在评价！
# 502.	正品，声音我觉得比K3003好，最大的问题是听诊器效应。
# 503.	东西不用说了 肯定是正品 正在保 现在低音下潜不够 烧烧看。。。。。
# 504.	刚收到正在煲，从网上查询是正品，以后音质应当不会差，相信森海，喜欢森海的声音。
# 505.	还可以，高频有毛刺。
# 506.	音质不错，我觉得可以，煲一阵子再看吧
# 507.	低音下潜有力，声场够大。一耳朵喜欢……
# 508.	听了一个多月，还不错，期待越来越好听！
# 509.	比我想象的小的多，音质煲了再追评。
# 510.	体验非常好，声场真的超棒，就是线材太短了点
# 511.	一直说ie800 人声不行 听着也不错啊
# 512.	还行吧，反正比手机自配线好(?▽?)
# 513.	耳机效果不错，价格贵，包装比较旧，还没有封条。配送及时。
# 514.	确实是旗舰级的，不错的
# 515.	活动买的，买完后就恢复原价，感觉捡了个大便宜
# 516.	耳机确实不错，带了就不想用原来的Airport了。
# 517.	IE800效果棒棒哒棒棒哒！我不懂耳机啊！哈哈！
# 518.	视频比IE80量少了，不过整体还不错。高频就好很多了。
# 519.	价钱不错，?不好，还没听出效果。
# 520.	非常好的耳塞。音质很赞，就是小了点
# 521.	不错的产品 煲机中 旗舰产品应该还是没的说
# 522.	初听不错  再听一段时间再追评
# 523.	耳机很好，就是不习惯带入耳式的，以前一直用头戴式的
# 524.	音质好不错的耳机样子也好看
# 525.	时间戴长了，耳朵痛
# 526.	旗舰塞，没得说，好评好评
# 527.	音质全方位好于ie80s！
# 528.	发货快质量好价格优惠，还行。
# 529.	最上火的一次购物，刚到手就便宜200元！
# 530.	入耳包装，深海依旧不好，不过煲过后还不错～
# 531.	618入的，还算便宜吧
# 532.	经典的塞子，难得好价，入手一条，声音挺好。
# 533.	东西还没拆 但是快递员很好！加个鸡腿吧 哈哈
# 534.	没对比过同价位的产品，自我感觉还好吧。
# 535.	已第二副了，实在喜欢，等IE800S上市了再入手。
# 536.	彰显音乐活力，动态冲劲，高频刺激，低频有力!
# 537.	东西感觉不错，正在煲机中，查了是正品！
# 538.	期待已久，是正品，找到自己想要的音质。
# 539.	声音通透、声场也不错。但佩戴真的是硬伤。
# 540.	大品牌，音质不错，值得拥有。
# 541.	挺好的耳机不错，刚听有些震耳朵，听几天就好了
# 542.	这耳机解析是真的厉害，不愧是大品牌。
# 543.	正品没问题，喜不喜欢都属于风格问题。
# 544.	不错的产品，相信京东和声海
# 545.	耳机不错，不过煲机还没到时间，先听着
# 546.	听了一下还可以，煲一下应该会更好，值得购买
# 547.	音色清澈，解析力强，陶瓷质感好。
# 548.	大品牌，还不错。。。。。
# 549.	基本已煲开，确实比3003好
# 550.	听了十多天才来评价，现在煲开了声音真不错，退烧神塞!
# 551.	防尘罩有一个憋，颜值很高，懒得换了
# 552.	好家伙，只是在手机上听听就已经不错了。
# 553.	越觉恢宏大气，解衣磅礴，相比之下，之前手里碌碌平庸的那些耳塞，直土鸡瓦狗，不堪一击。
# 554.	物流块质量好，活动价购买。
# 555.	做工音质都没的说，再便宜点就好了
# 556.	还是不错的，众所周知，人声弱了点~
# 557.	双十一优惠价还是比较好的，音质也是旗舰，听器乐相当好
# 558.	外观做工还可以的，音质还可以的。
# 559.	商品不错，物流快，快递小哥服务好
# 560.	不错的耳机，一直想买的，效果不错！
# 561.	前段是七彩虹C四，听下来感觉不错
# 562.	样子不错，没有跋扈的高调，却有低调的张扬
# 563.	感觉不错，听起来是和以前不一样
# 564.	还可以了，也算是旗舰款，可以听听
# 565.	发货快，好评！好评！好评！好评！好评！好评！好评！好评！好评！
# 566.	买的最贵的一条耳机，真货3788买的不算最便宜，但是价格不错，物流让人糟心！
# 567.	东西很好，物流很快，态度也非常好，是一次愉快的购物体验！
# 568.	不错，听郭德纲用还行
# 569.	还不错啊，是正品，音质也还不错，算是退烧选择了
# 570.	看了好几年了 剁手下单，退烧。
# 571.	稳。。。。。。物流快，货是正品
# 572.	升级耳机，声音好听多了，值得拥有。
# 573.	还可以！！！！！！！！便宜！！！！！！
# 574.	发货挺快的，哪怕是在618，塞子正在听，慢慢煲
# 575.	今天下午才送到手，试听了一下还行，在煲煲，
# 576.	正品没问题，高中低音均衡，低音给力。
# 577.	降价买的，比海淘还便宜。还没煲开，一耳朵还行。
# 578.	效果不错，价格也不错。
# 579.	森海塞尔的牌子还是不错的
# 580.	不错   俩耳朵都响
# 581.	好东西 只是目前手上还没有向心的播放器
# 582.	质量不错。好好好好好好好。
# 583.	音质不错吧，价格也可以
# 584.	还不错，下个入手谢兰图
# 585.	塞子不错，价格挺好的！
# 586.	孩子蛮喜欢  品质不错 值得购买
# 587.	挺不错的，我木耳都有提升，还不快买？？？？？
# 588.	清纯的音质，就像一杯好酒，值得细细品味
# 589.	送货快，价格也便宜，天天6.18不好么？
# 590.	东西看着不错，等用了之后再来谈感受！
# 591.	应该是真品吧，目前听的还不错
# 592.	大品牌就是不一样，一如既往的好，京东永远值得信赖
# 593.	停产之前来一条，美滋滋
# 594.	货真价实好东西音质好
# 595.	貌似二手，音质还行，算了
# 596.	耳机的声音挺舒服，三频均衡
# 597.	音质不错，刚试，感觉可以！
# 598.	耳机不错 还需要煲!!!
# 599.	音质比80又有进步，声场更宽
# 600.	耳机音效蛮好，只不过才买就出异常。
# 601.	还在煲机中！低音效果不错！
# 602.	线真是漂亮，刚听5小时，挺好<br />
# 603.	清脆 清晰 自然 舒服
# 604.	音质没得说，资料中好
# 605.	低音饱和丰满,适合听流行音乐
# 606.	正品不错，试听了，配zx1就好
# 607.	好音质，好的搭配，这这享受了
# 608.	不错，是我买的最贵的耳机了
# 609.	值得拥有，高音通透，低音浑厚。
# 610.	耳机以验货，正品无疑，还在煲机中
# 611.	刚刚到手，试用过，效果不错！
# 612.	效果超级棒，贵点，但老公说值
# 613.	产品质量不错，达到预期的效果。
# 614.	相信自己的耳朵，你值得拥有
# 615.	非常感谢京东商城给予的优质的服务，从仓储管理，物流配送等各方面都是做的非常好的，送货及时，配送员也非常的热情，有时候不方便收件的时候，也安排时间另行配送，同时京东商城在售后管理上也非常好，以解客户忧患，排除万难，给予我们非常好的购物体验！物品高端大气上档次，低调奢华有内涵，我看了就喜欢，用了也喜欢，如果可以继续买，我也愿意，下次肯定会买，值得得买，遇到像这样好的商品，一定要买，支持，京东的商品值得信赖，这些年一直支持，不用自己跑商场，送货上门，送货员态度很好，动动手指，东西到家，这种方式给我很多方便，所以以后会经常来京东买东西.
# 616.	全新，正品，音质完美。
# 617.	还不错，在用用看看吧~
# 618.	要求好前端，烧烧烧，继续烧
# 619.	超赞的声音，犹如天籁
# 620.	超给力的耳机，买了第二个了。
# 621.	物有所值，不错。包装盒设计可以再提高。
# 622.	好评，等煲开再感受！物流快！
# 623.	东西不错，只是低频浓重。物流很给力。
# 624.	小而强大的耳机，不愧是森牌的出品。
# 625.	低音强，动态大，解析高
# 626.	这个不错的可以价格也实惠的
# 627.	耳机音质不错，外观也还ok
# 628.	巴适哦，价格也巴适，
# 629.	不愧是旗舰，素质很好，低音特别好
# 630.	音质不错，值这个价。。
# 631.	送货速度快，服务态度好
# 632.	只能说京东的服务的确不错……
# 633.	试听了一下，音质不错。
# 634.	还不错，品牌可以，质量也算好
# 635.	不错，不愧为顶级耳机！值得拥有！
# 636.	还可以也就值这个价格
# 637.	质量不错。送货快。相信京东。
# 638.	公司采购，送货速度快，好东西值得信赖
# 639.	不错的产品，音质不错
# 640.	送货速度快，耳机音质不错
# 641.	京东省时省力，送货快，快递员不错
# 642.	森海塞尔耳塞品质有保障
# 643.	还不错，以后有需要还会继续购买
# 644.	收到，效果无敌，值得信赖
# 645.	东西不错，性价比高，包装精美。
# 646.	送给老婆的生日礼物，值得拥有！
# 647.	信赖京东自营，再接再厉！
# 648.	目前用过最舒适的耳塞
# 649.	不错，送自己的生日礼物
# 650.	物流速度快，帮朋友买。
# 651.	东西不知道怎么说 价钱不错
# 652.	东西不错，给朋友买的。
# 653.	这个价位的东西应该不错
# 654.	总体感觉不错，使用中
# 655.	不错，好贵呀，，，，，，，
# 656.	还没入手前端，ipx先推，糊得一塌糊涂，用了QQ音乐，~云，虾米，酷狗，感觉这玩意假的吧…applemusic听了he’sapirate?，一脸震撼，期待入手前端煲开。
# 657.	没有惊喜，MI6虾米直推没感觉那里好，失望。就是成交价格上还行，20180606下单3099-券40-豆70=2989，不会一定要上D100才行吧。(*^▽^*)
# 658.	算是支持一下森海塞尔吧，入了IE800，还没听，不过凭森海的口碑，应该值得期待，下一步准备入多一个sony或者iriver的前端，嗯，就这么多吧，剩下的等用过一段时间后再回来追评，
# 659.	用ZX-100推700兆一首的2L录音乐曲，对比之前的千元塞确实是一耳朵提升，刚开声无法评价，过些时间再续评
# 660.	音质不错，就是做工感觉很粗糙啊。和我同事的大法N3相比，我这个看着像地摊儿货。
# 661.	自大馒头蓝牙版之后 再入IE800入耳机皇 该退烧了 前端我用索尼zx100完全推得动 iPhone肯定也没问题 好多评测说多难推 你们真的用过么……
# 662.	包装好旧，一看就是被拆过的！懒得纠结换了，还好没洁癖，能用就行！
# 663.	充值信仰，这是目前最贵的耳机，不过喜欢就无所谓了。刚收到货大概试了下解析方面没得说，其他的等煲完再追评。估计此宝可以降温了，不知道晚上耳朵?会怀孕不？哈哈哈……
# 664.	煲的差不多了，购置了前端，搭配音质非同凡响。解析度高，人声无敌了。器乐暂时听得较少，不过听过的曲目很棒的。不过“耳屎收集器”这个绰号是肯定的，不过音质好这些都可以忽略了。希望以后还有其他更换部件陆续出现（如链接线等）。
# 665.	买了它，搭配fiiO SK-BTR3当蓝牙耳机用，以前在三里屯旗舰店听过，当时就种草了，奈何穷学生一枚，现在工作了终于拔草了。就是这声音，不可描述?，听岳云鹏相声，能定位后面倒数第三排，右边第二个人的叫好声!
# 666.	拿到就迫不及待的试听了下！可能是因为还没煲过 没有那种惊喜感。希望随着时间推移效果能越来越好
# 667.	简单使用，一时头脑发热买的，要吃土好一阵子了，但是听流行真的不需要这个级别的耳机。
# 668.	在直推，声场跟我的歌德s#5e有不小差距，先给个5星吧，过两天搞个播放器再说
# 669.	外包装被压的变形了，里面幸好没事。目前黑钻煲机中，过段时间再来追评
# 670.	实测 用水果x还是不如c5推的有力度 考虑到便携性 以后再入手前端吧
# 671.	此物乃听大编制交响乐之上古神器，够爽！PS:不要跟大耳相比不在一个频道哦！
# 672.	包装应该开过，这个不能在意太多了。声音还可以，要多听听，慢慢适应吧！
# 673.	已有lE80、双11再再入手lE800、初听差异不大，煲机中，期待！
# 674.	在购物车里放了一年了，就等这一天呢，从5699直接干到3999，用券再减211，保价再减210，完美！
# 675.	不说什么，一代经典，收藏了，出街凑合一下吧，
# 676.	货到了 还没有拆封 因为800比800更加纯粹 所以虽然是老款依然选择了它 等听了再来追评
# 677.	ie800多的就不说了，好玩意，煲机当中。后续给听后感。ie60  ie80  都有
# 678.	入耳就这样吧，正常体会没啥惊喜，肯定不会是最后一个耳机。买买买
# 679.	森海旗舰，种草已久，编号五万多了。开声效果普普通通哦。
# 680.	这个价格我认为已经达到了心里价，所以果断拿下，好好享受森海的顶级动圈吧~~话说耳机线确实存在隐患，上面的线如果废了那就不好办了
# 681.	照片就不晒了，塞子到手，开声就知道一定要煲，目前正在和X7连续播放。今天谈谈第一感：低音饱满厚实，中频勉强中规中矩，高频没有发开，还谈不上解析，一切皆等煲开再来追评。（如果记得的话）！
# 682.	请问带着耳机上街，会被大爷大妈拉住强制介绍对象么。。
# 683.	80丢了 心痒了好久才下单800的  可能是没煲开的缘故个人感觉 80比800更舒服 所以说耳机是玄学适合自己的才是最好的 准备有闲钱再入一条80  800已送给心爱的姑凉，愿她天天开心
# 684.	音质好到爆炸.刚开始听高频有点刺耳.煲开了应该就好了.
# 685.	森海赛尔入耳式耳机中的………哈哈………耳机中战斗机！
# 686.	抛ie80一条街，一分钱一分货，早买早享受，退烧必备！3240到手，免息分6期。
# 687.	初步的效果跟我用了3年的IE80差别不大，希望小火煲熟后有所提升，如果单从乐器方面IE800真的没得说，最不好的就是老带不稳，几千快钱的耳机还能犯这么低级的错误，所以这里扣1星，下次再入条不同风格的AK3003试试。
# 688.	跟535比人声的时候我哭了，跟3003比交响的时候我笑了。
# 689.	比ie8小巧，刚入未褒机，初次听感一般，期待褒机后表现
# 690.	收到了 用苹果手机听 比一千多元的bose耳机略好 多煲一下再评 也许手机就是这个效果吧
# 691.	买回来两天了，比我另外一款好几年的CX150差不多，还在煲音，看看2个月之后的表现，很期待
# 692.	正常使用，没有什么问题，声音略有些失真，正在继续听
# 693.	生草很久了，放在购物车里就等双11了。具体说吧，各科90分，全能学霸。
# 694.	音质超出预期，没有k3靓丽，但多了一些温暖！
# 695.	这套装备一上，别无所有求了。暂时哈哈
# 696.	森海塞尔我人生第一个耳机就是px100,这次一如既往的选择
# 697.	还是回归大动圈帝国，一耳朵通透，待煲100小时
# 698.	第一次买HiFi耳机，打算初烧即退烧，这玩意追求起来无穷无尽，有这副耳机再加个过得去的前端凑合过吧。。。
# 699.	刚到手试听，齿音明显。but其他优点突出，希望煲机后会有改善
# 700.	除了佩戴反人类，其它都优秀，ie80听了6年，该退休了。
# 701.	还在煲，森海家的耳塞基本算是我的标配了。。。MX200、365、500到CX200、870、985到IE8、80、800。。。终于算是到头了唉。。。
# 702.	京东小哥很给力，速度快，但包装太简陋，四个角都磨砂了，送人差点意思了！
# 703.	刚拿到手，与期待值有一定距离，需要煲机的？
# 704.	和k3双修了，k3听多了再听ie完全不一样的感觉，低频明显能撑起歌曲的氛围感
# 705.	给老板买的，还没来得及蹭听，据说不错。一万多号。只看到盒子，居然是德国产的，上面标的是德国设计，组装，生产。是真的吗？
# 706.	双11买的。初入HiFi坑，耳机还在慢慢使用中。也入了索尼的PHA-3，音效不错。
# 707.	教大家一个解决听诊器效应的办法 绕耳佩戴
# 708.	可以吧 目前没发现有什么不舒服的 毕竟钱到位了
# 709.	认准这标志，一眼就是一辈子
# 710.	四大旗舰入了三个 第一耳朵的直观感觉就是ie800真的欠煲 一百小时以后期待什么效果
# 711.	配zx300的4.4 还可以 准备试试spk的2.5
# 712.	听着和五元耳机差不多因为刚拿到手？没推了而且手机带？等推来了试试
# 713.	对于这种级别的耳机，包装和配件都简陋了。耳机还没有煲开，对于音质的表现还无法评价。
# 714.	开声打不过60可还行……低音下不去，高音刺耳，正品无疑了
# 715.	买过，最贵的耳机，没有之一，期待煲开音质
# 716.	森海的包装做得好。东西收到时没开过封。初听感觉潜力巨大。可能需要加个耳翼。
# 717.	夸森海包装做得好，是因为京东送货只套了个有京东logo仅塑料袋，扯开一看，森海的外包装盒象被狗啃了一样，布满了很深的牙齿状凹坑，但里面东西是好的。
# 718.	80赶紧升级80赶紧升级80赶紧升级，估计要停产，就这么多
# 719.	送给男票的，兴奋得不得了，以前有一个丢了，拿到之后就迫不及待的开始煲机了。
# 720.	还没用，不过我先的80s细节，乐器表现不错
# 721.	买了800买了3003，暂时还是觉得3003更好些
# 722.	刚入手几小时，用葛莱美旅行者推，较IE80无本质区别。煲一段时间也许会有改善。
# 723.	好东西，还没煲机呢就与艾利和AK240配合后才知道什么叫移动的音乐，原来IE80那个东东只能叫移动的声音了！
# 724.	活动期间价格都会变来变去，从来没办过价格保护，不知道规则，朋友告知时价格已恢复不能办了，（
# 725.	东西还是可以的~有些评价也是个人思想~效果肯定可以~毕竟是知名品牌
# 726.	就冲这个频响5-46500hz必须给5星，16欧阻抗连ipc也能轻松推起，一根顶配无需更替了。
# 727.	还没完全煲开，上班忙也没时间听，过阵子忙完了再慢慢品，以后再追加。
# 728.	3499入手，初听就比80强不少，期待后续煲机的效果！
# 729.	森海新旗舰，特价收一个吧
# 730.	还没开始煲，希望煲开后不会失望
# 731.	很不错音质很好，感觉不需要煲机就已经很好了。
# 732.	小耳机，大声限，正在堡，不知道后面如何？
# 733.	5S直推 跟苹果自带的耳机效果差不多 看来需要上pha-2 可惜京东没有
# 734.	刚开始听真的不知道哪里值这么多钱，后面听多了还好吧。
# 735.	上耳感觉一分钱一分货  ，还好， 正在煲机中。
# 736.	新耳机刚到手用手机听，感觉像初生的嫩芽
# 737.	煲了两天，体验简直了！?
# 738.	活动实在是实惠，逼着我没钱也要买。＾?＾别让我失望！
# 739.	之前的800丢了，哭………所以又买了一条
# 740.	从HD600到IE800，想退烧了。
# 741.	还好吧，跟AKG K3003 差不多吧，都是iPhone用的耳机
# 742.	不知道手机推不推得动，过几天再买个好点的前端吧。
# 743.	听古典交响的利器，解析比IE80提高一个台阶。
# 744.	初步听了一下，感觉是高档耳机。煲一阶段再继续评价。
# 745.	经典的声音，期待200小时后的表现
# 746.	要是有个耳机袋就完美了
# 747.	听到了，是R**的声音
# 748.	东西收到，正在煲机中，初听还可以
# 749.	为信仰充个值 低音劲中音准高音甜 一句话就是通透
# 750.	给同事买的，价钱真是历年最低
# 751.	森海塞尔（Sennheiser） IE800 入耳式HiFi耳塞 黑色 旗舰
# 752.	听诊器效果出众，戴着有种主任医师的感觉
# 753.	森海塞尔（Sennheiser） IE800 入耳式HiFi耳塞 黑色 旗舰
# 754.	先留着吧，这样搭配应该没有错。
# 755.	交响来说 没其他选择了 这个价位
# 756.	东西收到，分不清真假，等试用一段时间再说，希望京东坑不深。
# 757.	听听古典和人声还行，其他的不想多说了
# 758.	IE800也许是我今年最后买的一款耳机，该退烧了
# 759.	森海塞尔（Sennheiser） IE800 入耳式HiFi耳机 旗舰
# 760.	是正品，刚开声并没多大惊喜，期待煲开后的表现
# 761.	其实我也想好好写个评价，但是30个京豆太不划算！
# 762.	不是特别惊艳 可能还需时日
# 763.	双十一价格算是到底了，赶紧入手这款经典塞子，等IE800s上市
# 764.	还得磨一段时间，才能出彩
# 765.	一般般啦的时候的时候的时候的时候
# 766.	正在煲机中 音质有待慢慢提高，期待中
# 767.	在煲机中，刚开始听，确实吓一跳，还不如我的白牙........
# 768.	森海塞尔品牌的耳机用了20年还在服役，ie800令人惊叹
# 769.	还没开始用，因为连接他的MP3还没到货。不过应该不错
# 770.	买完IE80s买的这个，嗯，真香。
# 771.	还好吧，可以接受!<br />容易掉……
# 772.	这个设备是我见过最好的设备了，还需要煲一段时间
# 773.	关注很久的东西，下决心在双十一出手，还需要慢慢体会和享受！
# 774.	比升级了4.4金宝线的W40要好听。
# 775.	还没开始听，等听后再评。
# 776.	煲机进行时煲机进行时煲机进行时煲机进行时
# 777.	一万以内听个响吧，接收音机用的。
# 778.	希望物有所值，千万别徒有虚名。
# 779.	对得起3099，也没有惊喜。
# 780.	刚买没几天，效果比一般耳机好了许多，煲开会更好吧
# 781.	还没煲开 sp1000驱动
# 782.	这个耳机，根本就不需要评价了，效果大家都知道！
# 783.	神器,不解释,果断丢弃了我的魔音耳机!
# 784.	处于煲机阶段，煲机后再来评价
# 785.	换货成功 剩下的就看质量了
# 786.	货已收到，等充分煲透后分享
# 787.	那还用说的吗，钢钢的。
# 788.	买的第一个hifi入耳式耳机，期待一下
# 789.	一分钱一分货，音质确实通透
# 790.	听不出区别，哈哈哈哈
# 791.	还在煲 等完成后追评
# 792.	很可以 服务就很棒
# 793.	还有什么可说的，4000内最好的选择
# 794.	氛围没的说，原汁原味
# 795.	刚到手，听听再说！
# 796.	煲几十个小时就行了，声音很自然，和索尼相比不像监听耳机。有人说耳塞容易从耳孔脱掉。本人用着不掉。
# 797.	耳机目前欠煲，开声无感
# 798.	验过是正品！ie800还用什么描述吗！
# 799.	开始买了以为是假货，煲机80小时后有惊喜。
# 800.	音质不知道，已经赔给朋友了
# 801.	关注了多时，趁活动赶紧购买了。
# 802.	入耳式中最大的声场，不愧旗舰之名。
# 803.	窥窃很久了，赶上京东音响节，就收了
# 804.	帮朋友买的，也不知道，但一定很给力
# 805.	Sennheiser） IE800 入耳式HiFi耳机 旗舰
# 806.	比较难推好
# 807.	现在还一般！等过段时间再说吧！
# 808.	森海粉，家里近10款森海各种耳机
# 809.	还好吧，听感没想象中好。
# 810.	顶级耳机 配合耳放 古典乐无敌了
# 811.	还在煲机。不知道啥时能出期待中的效果。
# 812.	还没上前端，听不出有多大效果
# 813.	为耳朵买的奢侈品。毕竟一份价钱一分货
# 814.	是我要的声音 越听越好听......
# 815.	梦寐以求的耳机终于到手了，开始煲机
# 816.	不知道是不是正品，扫码都无效
# 817.	三频均衡，音色清丽，但声场，密度和天狼星比真是差太多
# 818.	旗舰入耳耳机，退烧神器，正在煲机中！
# 819.	熟悉的声音，经典就是经典！
# 820.	刚买，听段时间再说！！！！！！！！！！！！！！！
# 821.	煲中，没有什么一耳朵惊喜,慢慢来吧。
# 822.	此用户未及时评价，系统默认好评。
# 823.	加个耳放，效果棒极了
# 824.	此用户未及时评价，系统默认好评。
# 825.	如果已经有了ie80,就不建议再买这个了，声音是好一点点，但是佩戴实在是太差劲了，关键是还不能换线
# 826.	此用户未及时评价，系统默认好评。
# 827.	京东自营服务周到
# 828.	没有失望 越听越喜欢
# 829.	正在煲机中 终于出点效果了
# 830.	效果可以 待磨机过后在品
# 831.	以前买的k3003，换个试试
# 832.	经典旗舰，没什么好说的了。
# 833.	不要求苛刻的话着耳机就通吃le
# 834.	声场开阔低音下潜深搞活时入手滴4689
# 835.	东西可以。。。。。。。。。。。。东西可以。。。。。。。。。。。。东西可以。。。。。。。。。。。。
# 836.	不错不错
# 837.	挺满意的
# 838.	森海塞尔现阶段顶级旗舰耳机
# 839.	没什么好说的，第一声便是惊喜。
# 840.	果然神奇，简约炫酷，正在慢煲中
# 841.	除了佩戴 其他没话说。
# 842.	最大的感受就是气势恢宏
# 843.	刚收到，正在听。。。。。。。。。。。
# 844.	很好
# 845.	满意
# 846.	分享
# 847.	有比我還玄學的麼
# 848.	很好一级棒正在煲
# 849.	手机直推明显声音干涩。
# 850.	正在爆机，回头追评
# 851.	这下牛逼了 我的IE8要退伍了 下个k3
# 852.	我觉得可以
# 853.	不错，慢慢煲鸡中
# 854.	到现在不会后悔入手了
# 855.	搭配什么播放器？
# 856.	暂时没有什么不好的。
# 857.	森海塞尔的旗舰产品懂的自然懂
# 858.	宝鸡中 <br />很不错
# 859.	送媳妇的新年礼物，希望她能喜欢。
# 860.	第二次买了
# 861.	帮别人买的 不知道怎么样
# 862.	第一次送来的明显打开过后面换来的还可以
# 863.	旗舰入耳式耳机 一分钱一分货
# 864.	音色偏冷，需要煲久一点
# 865.	犹豫两年，秒杀一切音乐
# 866.	京东真的给力！祝京东越来越好！
# 867.	京东真的给力！祝京东越来越好！
# 868.	一如既往的高品质，值得拥有！
# 869.	赞一个！！！
# 870.	品质和物流五星好评
# 871.	大品牌，正在使用中…
# 872.	应该不会差吧。。。。。
# 873.	深海的东西，不多说了。
# 874.	还没用，希望效果不错！
# 875.	还行 第二次买 重新煲
# 876.	绝对是顶级的耳塞
# 877.	好？？？？？？？？？？
# 878.	好。
# 879.	还没煲开，暂不评论！<br />
# 880.	刚煲完，确实是好
# 881.	刚到手，感觉不错
# 882.	非常不错的耳机
# 883.	引起确实不一样。
# 884.	买这耳机还是要前端
# 885.	拆封过的，不知道该怎么评价了
# 886.	挺好的，一耳朵差距
# 887.	耳机正品，音质很好
# 888.	万元以内听个响
# 889.	听起来真的舒服?
# 890.	一般人不懂  东西不错的
# 891.	旗舰耳机没得说
# 892.	真的没啥特殊的心得！！！
# 893.	还在煲机中
# 894.	挺好的  烧无止境
# 895.	完美越用越爽
# 896.	音质很好很棒
# 897.	非常不错
# 898.	非常满意
# 899.	破。。。费！完美！
# 900.	听古典真#完美
# 901.	超给力啊。。。一分价钱一分货。
# 902.	商品质量不错
# 903.	不错，因你开始，由你结束，但愿每个人都有一个美好的结局，加油吧少年，从今天开始心里不会再有你，开始为自己活着吧
# 904.	还行吧  不错
# 905.	不错吧
# 906.	不错是正品！
# 907.	宝贝不错?
# 908.	心满意足
# 909.	不错的选择
# 910.	还没有使用。
# 911.	音质不错！
# 912.	完美完美
# 913.	活动买的平时太贵。c?c?c?c?c
# 914.	古典专用
# 915.	很好，不错
# 916.	听听再说
# 917.	一分钱一份货是无争的事实，本人从ie60到80S，再到现在刚入手的ie800，前端是乾龙盛361M0D，800在没煲的前提下己超越了用挺长时间的80S，期待用段时间后给出更好声音，这货3199元值的入手。
# 918.	价格一般东西还凑合吧
# 919.	京东没有让我失望，不枉我一直信赖
# 920.	非常好
# 921.	非常好
# 922.	音质好
# 923.	挺好的
# 924.	可以吧
# 925.	贵，无他
# 926.	强大
# 927.	刚收到，试试！！！！！
# 928.	很好
# 929.	好评
# 930.	帮朋友买的！！！！！
# 931.	煲机中。。。。。。。。。。。
# 932.	非常感谢京东商城给予的优质的服务，从仓储管理、物流<br />配送等各方面都是做的非常好的。送货及时，配送员也非<br />常的热情，有时候不方便收件的时候，也安排时间另行配<br />送。同时京东商城在售后管理上也非常好的，以解客户忧<br />患，排除万难。给予我们非常好的购物体验。<br />Thank you very much for the excellent service<br />provided by Jingdong mall,and it is very good to do<br />in warehouse management,logistics,distribution and<br />Delivery in a timely manner,distribution staff is<br />sO on.<br />also very enthusiastic,and sometimes inconvenient<br />to receive the time,but also arranged for time to be<br />delivered.At the same time in the mall management<br />Jingdong custTha
# 933.	牛。
# 934.	赞?
# 935.	好！
# 936.	还在煲机，听着不错
# 937.	货真价实！！！！！！！
# 938.	不错 给基友买的
# 939.	不错的购物体验。
# 940.	入坑塞，可以可以
# 941.	等煲好在评论
# 942.	旗舰就是旗舰
# 943.	煲机中，挺好的
# 944.	以前从来不去评价，使用京东几年来不知道浪费多少评价，自从知道评价可以升级会员等级的时候，才知道评价的重要。后来我就把这段话复制了，走到哪，复制到哪，即能升等级，又能么么哒
# 945.	双11入手的黑砖，双十二再入手IE800
# 946.	万元以下听个响系列
# 947.	非常好
# 948.	新耳塞还要煲一煲
# 949.	还可以
# 950.	啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊
# 951.	好品牌
# 952.	还行
# 953.	还行！
# 954.	很棒
# 955.	森海塞尔不错～～
# 森海塞尔不错～～
