# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import re
from time import sleep
profession = "Python"
filePath = "职业信息.csv"
soft = ['职业', '工资','城市','工作经验','学历','公司名称','公司类型','链接']
sums = 40
def enter(driver,url):
    driver.get(url)
def find(driver,name):
    count=0
    driver.find_element_by_name('query').clear()
    driver.find_element_by_name('query').send_keys(name)
    driver.find_element_by_xpath(r'//*[@id="wrap"]/div[3]/div/div/div[1]/form/button').click()
    items=driver.find_elements_by_class_name('job-primary')
    lists=[]
    while(count<=sums):
        for i in items:
            good=[]
            link=i.find_element_by_tag_name('a').get_attribute('href')
            profession=i.find_element_by_class_name('job-title').text
            emolument=i.find_element_by_class_name('red').text
            city=i.find_element_by_tag_name('p').get_attribute('innerHTML').split('<')[0]
            work_experience = re.search(r'(?<=em>).*\w+(?=<em)',i.find_element_by_tag_name('p').get_attribute('innerHTML'))[0]
            education_background = i.find_element_by_tag_name('p').get_attribute('innerHTML').split('>')[-1]
            companyname = i.find_element_by_class_name('company-text').text.split('\n')[0]
            companytype = i.find_element_by_class_name('company-text').find_element_by_tag_name('p').get_attribute('innerHTML').split('<')[0]
            good.append(profession)
            good.append(emolument)
            good.append(city)
            good.append(work_experience)
            good.append(education_background)
            good.append(companyname)
            good.append(companytype)
            good.append(link)
            lists.append(good)
            print(good)
            count+=1
            if(count==sums):break
        if(count==sums):break
        next = driver.find_element_by_class_name('next').get_attribute('href')
        driver.get(next)
        #driver.find_element_by_xpath(r'//*[@id="main"]/div/div[3]/div[3]/a[5]').click()
        sleep(1)
        items = driver.find_elements_by_class_name('job-primary')
    return lists
def writeList2CSV(myList,filePath):
    try:
        file=open(filePath,'w+')
        myList.insert(0,soft)
        for items in myList:
            for item in items:
                file.write(item)
                file.write(",")
            file.write("\n")
        print("爬取成功!")
    except Exception :
        print("数据写入失败，请检查文件路径及文件编码是否正确!")
    finally:
        file.close()
if __name__ == "__main__":
    driver=webdriver.Chrome()
    enter(driver,"http://www.zhipin.com/")
    sleep(1)
    allInfo=find(driver,profession)
    writeList2CSV(allInfo,filePath)
    driver.quit()
# Out:
# ['Python', '10k-15k', '杭州 滨江区 长河', '1-3年', '本科', '软通动力', '计算机软件', 'https://www.zhipin.com/job_detail/9078cc694e34675c1XR92d--FVE~.html']
# ['Python', '20k-40k', '杭州 西湖区 西溪', '3-5年', '本科', '蚂蚁金服', '互联网', 'https://www.zhipin.com/job_detail/1a4d83665af11d741HV80ty6FFo~.html']
# ['Python', '10k-20k', '杭州 西湖区 转塘', '1-3年', '大专', '软通动力', '计算机软件', 'https://www.zhipin.com/job_detail/4df70d605f89b0881nF_39y1GVQ~.html']
# ['Python', '15k-25k', '杭州 西湖区 ', '5-10年', '大专', '软通动力', '计算机软件', 'https://www.zhipin.com/job_detail/5160f69d516cb6c71XR53dm4GFU~.html']
# ['Python', '10k-20k', '杭州 滨江区 长河', '3-5年', '本科', '新华三技术有限公司', '计算机软件', 'https://www.zhipin.com/job_detail/661821bcd9959c1a1Xx52t64FFE~.html']
# ['python', '12k-18k', '杭州 西湖区 西溪', '3-5年', '大专', '博彦科技', '计算机软件', 'https://www.zhipin.com/job_detail/d7887ea3aef7b9c51HVz39-7GFc~.html']
# ['Python', '11k-18k', '杭州 西湖区 转塘', '3-5年', '大专', '中软国际', '计算机软件', 'https://www.zhipin.com/job_detail/fe5217b5bb46c6d31XF_29S5E1Q~.html']
# ['Python讲师', '10k-15k', '杭州 拱墅区 古墩路', '经验不限', '学历不限', '小码教育', '在线教育', 'https://www.zhipin.com/job_detail/997fd22720455bdc1XR-2tq8EVs~.html']
# ['Python', '15k-25k', '杭州  ', '3-5年', '本科', '小影', '移动互联网', 'https://www.zhipin.com/job_detail/4404288cb2f7f6811Hdy29y8E1E~.html']
# ['Python', '13k-24k', '杭州  ', '3-5年', '本科', '杭州蜂飞科技有限公司', 'O2O', 'https://www.zhipin.com/job_detail/25384bd903825c521Hd809S5EFY~.html']
# ['Python教学讲师', '10k-15k', '杭州 拱墅区 古墩路', '经验不限', '学历不限', '小码教育', '在线教育', 'https://www.zhipin.com/job_detail/7a5563721c5cf9c71XR-2NS4EFA~.html']
# ['Python教学讲师', '8k-13k', '杭州 拱墅区 古墩路', '经验不限', '本科', '小码教育', '在线教育', 'https://www.zhipin.com/job_detail/5b309f170d4960d91XR_2d61E1Q~.html']
# ['python开发', '7k-12k', '杭州 滨江区 长河', '1-3年', '本科', '软通动力', '计算机软件', 'https://www.zhipin.com/job_detail/6237f65cd89614f51HR83N-1FFs~.html']
# ['Python开发', '10k-20k', '杭州 滨江区 长河', '1-3年', '本科', '软通动力信息技术集团', '计算机软件', 'https://www.zhipin.com/job_detail/ca92ba7db00482891X1z2Ny4EVU~.html']
# ['python开发', '25k-40k', '杭州 西湖区 古荡', '1-3年', '本科', '蚂蚁金服', '互联网金融', 'https://www.zhipin.com/job_detail/43c2d6af81410f891nZ50t27E1U~.html']
# ['Python老师', '7k-12k', '杭州 西湖区 文二路', '经验不限', '本科', '傲梦网络科技', '在线教育', 'https://www.zhipin.com/job_detail/b033e19e8ffe73231Hd_2dS-FlA~.html']
# ['高级python', '18k-28k', '杭州 余杭区 仓前', '3-5年', '本科', '杭州默安科技有限公司', '信息安全', 'https://www.zhipin.com/job_detail/91fe34f522a706a21nx-2tW6E1o~.html']
# ['Python', '10k-15k', '杭州 西湖区 文一路', '3-5年', '学历不限', '中焯信息', '移动互联网', 'https://www.zhipin.com/job_detail/11be0b4f9c6536ee0HR93N61Fw~~.html']
# ['Python', '8k-15k', '杭州  ', '1-3年', '本科', '木链科技', '信息安全', 'https://www.zhipin.com/job_detail/0ffb78e2b8056b2a1nxy3Nq4GFE~.html']
# ['Python', '15k-30k', '杭州  ', '1-3年', '本科', '美登', '企业服务', 'https://www.zhipin.com/job_detail/66ebf8cecd37b5bb1Xd93t-6E1E~.html']
# ['python研发工程师', '15k-25k', '杭州 西湖区 古荡', '1-3年', '本科', '蚂蚁金服', '互联网', 'https://www.zhipin.com/job_detail/0821b7170c4ab96f1Hd609--GFY~.html']
# ['python开发工程师', '14k-20k', '杭州 滨江区 长河', '5-10年', '本科', '软通动力', '计算机软件', 'https://www.zhipin.com/job_detail/997697a2227327df1XF73ti-GFQ~.html']
# ['Python开发工程师', '12k-18k', '杭州 滨江区 长河', '3-5年', '本科', '软通动力', '计算机软件', 'https://www.zhipin.com/job_detail/d7cfc42f67ce78f71HV82Ny1FlM~.html']
# ['Python', '20k-25k', '杭州 余杭区 仓前', '5-10年', '本科', '杭州斑材科技有限公司', '互联网', 'https://www.zhipin.com/job_detail/bc0ac092fd551d081HV_39u8FVA~.html']
# ['高级Python研发工程师', '16k-20k', '杭州 滨江区 长河', '3-5年', '本科', '沃趣科技', '计算机软件', 'https://www.zhipin.com/job_detail/3db35627538e6e651XN639q6EVE~.html']
# ['软件测试（会Python）', '12k-18k', '杭州 滨江区 滨江区政府', '1-3年', '本科', '火石创造', '互联网', 'https://www.zhipin.com/job_detail/080bb2c2ccc1e3661HB62di9EFA~.html']
# ['资深Python工程师', '15k-25k', '杭州 滨江区 滨江区政府', '1-3年', '本科', '火石创造', '互联网', 'https://www.zhipin.com/job_detail/903efca7268362af1HV93t-_EVU~.html']
# ['Python后端工程师', '20k-35k', '杭州 西湖区 古墩路', '1-3年', '本科', '飞步科技', '互联网', 'https://www.zhipin.com/job_detail/666cd18c70732c171HZ929S7Elc~.html']
# ['Python 开发工程师', '15k-30k', '杭州 萧山区 北干', '3-5年', '本科', '微医集团', '互联网', 'https://www.zhipin.com/job_detail/49c146e534cddc6f1XN82N-0GFs~.html']
# ['Python全栈开发工程师', '12k-18k', '杭州 滨江区 西兴', '1-3年', '本科', '海康威视', '计算机软件', 'https://www.zhipin.com/job_detail/97abd3f7f63db0741Xx_0t21FFI~.html']
# ['中级python开发工程师', '12k-15k', '杭州  ', '1-3年', '本科', '安恒信息', '信息安全', 'https://www.zhipin.com/job_detail/40ce04a822e8542b1Hd839q9FFQ~.html']
# ['高级Python全栈工程师', '12k-16k', '杭州 余杭区 仓前', '3-5年', '本科', '蜂巢', '计算机软件', 'https://www.zhipin.com/job_detail/d1686fe6327984c61Hd60t68E1A~.html']
# ['Python高级开发工程师', '20k-40k', '杭州 拱墅区 万达广场', '3-5年', '本科', '京东数字科技', '互联网', 'https://www.zhipin.com/job_detail/836170221d6dc3451nN-0926E1o~.html']
# ['机器人-测试部-python开发工程师', '11k-22k', '杭州  ', '1-3年', '本科', '海康威视', '计算机软件', 'https://www.zhipin.com/job_detail/6354f5cf60c550491HZz0ti_GVc~.html']
# ['Python技术经理', '15k-25k', '杭州 萧山区 钱江世纪城', '3-5年', '本科', '数行科技', '数据服务', 'https://www.zhipin.com/job_detail/75db5c0c1e46c3e21HV83N-7GVc~.html']
# ['python 后端工程师', '14k-22k', '杭州 富阳区 ', '3-5年', '本科', '杭州智链达', '互联网', 'https://www.zhipin.com/job_detail/f338d06e8878caf41nZ90t-1GVs~.html']
# ['Python研发工程师', '8k-15k', '杭州 滨江区 长河', '1-3年', '本科', '沃趣科技', '计算机软件', 'https://www.zhipin.com/job_detail/175eeee5fab06ad71XN639q8F1Q~.html']
# ['高级Python工程师', '15k-30k', '杭州 拱墅区 万达广场', '3-5年', '本科', '博博科技', '医疗健康', 'https://www.zhipin.com/job_detail/86edeef2355cac041XN42tm5F1M~.html']
# ['Python青少儿讲师', '5k-10k', '杭州 上城区 平海路', '经验不限', '本科', '傲梦网络科技', '在线教育', 'https://www.zhipin.com/job_detail/9391c59429ca1c391HZ429u0FlY~.html']
# ['Python后端开发工程师', '15k-25k', '杭州 西湖区 西溪', '3-5年', '本科', 'Eigen', '移动互联网', 'https://www.zhipin.com/job_detail/a0b9b39241fb18df1nF929i6FVU~.html']
# 爬取成功!
