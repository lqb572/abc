# %%
import subprocess
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
import re,time

# %%
command = "\"C:\\Program Files (x86)\\Google\\Chrome\\Application\\chrome.exe\" --remote-debugging-port=9242 --user-data-dir=C:\chrome_profile"
print(command)
# Out:
# "C:\Program Files (x86)\Google\Chrome\Application\chrome.exe" --remote-debugging-port=9242 --user-data-dir=C:\chrome_profile

# %%
retcode = subprocess.Popen(command,shell=True)
time.sleep(10)
chrome_options = Options()
chrome_options.add_experimental_option("debuggerAddress", "127.0.0.1:9242")
driver = webdriver.Chrome(options=chrome_options)

# %%
driver.get("https://item.jd.com/34640640658.html")

# %%
driver.find_element_by_xpath(r'//*[@id="detail"]/div[1]/ul/li[5]').click()

# %%
reobj = re.compile(r'<p class="comment-con">([\s\S]*?)</p>')

# %%
comment = []
count = 1

# %%
def next_page(driver):
    # driver.find_element_by_link_text(u"下一页").click()
    parent = driver.find_element_by_css_selector('.ui-page')
    try:
        parent.find_element_by_link_text(u"下一页").click()
    except:
        time.sleep(2)
        page_num = parent.find_element_by_link_text(u"下一页").get_attribute('rel') 
        # ActionChains(driver).send_keys(Keys.SPACE).perform()
        # time.sleep(2)
        parent.find_element_by_link_text(page_num).click()
        # driver.find_element_by_link_text(u"下一页").click()

# %%
while True:
    html = driver.page_source
    result = reobj.finditer(html)
    if not result:
        print("找不到评论结束")
    for i in result:
        comment.append(i.group(1))
        print(str(count) + ".\t" + i.group(1))
        count += 1
    # for i in result:
    #     z = reobj1.search(i.group(1))
    #     try:

    #         comment.append(z.group(1))
    #         print(str(count) + ".\t" + z.group(1))
    #         count += 1
    #     except:
    #         pass
    # retry = 0
    
    try:
        next_page(driver)
    except:
        try:
            next_page(driver)
        except:
            break
# Out:
# 71.	手机是正品，用得非常爽，赠送礼品很多，十分喜欢，给好评！
# 72.	速度是真快，昨天下单，今天老早就到了。手机买来送人的，因此自己没有拆封，只拍了个外观。没想到还送了这么多配件，店家真贴心啊。5份好评！
# 73.	果然名不虚传，外观，手感都是一流的。反应真是太快了，相机更加强大，快递给力。
# 74.	质量非常好，很好用，颜值高，像素很高，拍的很清晰，生活的必备用品，你值得拥有！
# 75.	非常满意的一次购物，京东配送速度杠杠的！华为手机的质量值得信赖！商家赠送了很多实用的礼物(华为自拍杆、钢化膜、智能手环等等)，特别感谢热心和耐心的商家客服人员！
# 76.	很好用，还会下次购买，手机很好用，电池很好
# 77.	好漂亮，真的是很不错，速度很快，屏幕大也很清晰
# 78.	极光色颜色很漂亮，之前在实体店体验过，线上购买比实体店便宜。手机很漂亮，运行没的说，旗舰机贵，但是质量体验也很棒。很满意
# 79.	用了两周才来评说，980确实快，从苹果换回安卓，很快适应，操作界面好用，速度一级棒，商家也很好，中间出点问题，都一一解决了，赠品比华为商城多多了，拍照效果也很好
# 80.	物流挺快的，顺丰两天就到了，手机盒子还挺沉的，mate系列做工真的没得挑，三摄拍照真给力，特别细腻清晰，屏幕够大，横屏玩儿游戏看视频也挺爽的
# 81.	手机是正品，用得非常爽，赠送礼品很多，十分喜欢，给好评！
# 82.	速度是真快，昨天下单，今天老早就到了。手机买来送人的，因此自己没有拆封，只拍了个外观。没想到还送了这么多配件，店家真贴心啊。5份好评！
# 83.	果然名不虚传，外观，手感都是一流的。反应真是太快了，相机更加强大，快递给力。
# 84.	质量非常好，很好用，颜值高，像素很高，拍的很清晰，生活的必备用品，你值得拥有！
# 147.	给妈妈买的，她非常喜欢，屏幕大，照相清晰度很高，外观也很漂亮
# 148.	运行速度很快 屏幕也够大 看电影听歌很棒 吃鸡非常给力 满意
# 149.	很不错，实用性很强，允许流畅，不卡，拍照也清晰，满意
# 150.	手机非常好用，重量是我用过的最趁手的，速度很快，反省也很快，而且赠的东西也很多，完完全全一个直字
# 151.	很优秀，喜欢华为支持国产，等咯一天快递终于到了
# 152.	昨天下午去逛街时看了下新机，很是喜欢，回家立马京东下单，一直用的华为手机，这次出新品，果断下手，先说颜值，绝对秒杀苹果，性价比更是不用说了，大爱。华为国人的骄傲，加油！！
# 153.	很喜欢华为手机，据说这款能够放望远镜来用，我就买来试试，拍照效果真的不错，店家还送了好多小礼物，物超所值了。
# 154.	质量很好，满意的一次购物，还送的碎屏险及一些赠品
# 155.	拿到手里非常惊艳，极光色想了好看，果然好看。。980的CPU运行起来越快，非常爽。
# 156.	手机已到货，很好用，速度很快，满意～
# 157.	我是用了一周再来评价的，手机真不错，速度很快，有质感。外观上可以和苹果媲美啦，支持国产，支持华为！
# 158.	心心念念的手机到了，很流畅很漂亮，华为手机确实越做越好了，比苹果三星差差不多，很满意
# 159.	以前没有在网上买电子产品的经历，一直很忐忑，担心商家以次充好，通过这几天的使用，感觉很好，一次满意的购物！
# 160.	手机我三天收到了，我这里是广东江门，店家是从济南发货的，距离1800多公里，算快了，看到好多评论说物流要七八天，我都想退货了。由于我的手机烂得太突然，所以每天都来找客服，叫他们帮我催一下，客服的态度也很好，感谢。
# 161.	无法接受刚买了就降价
# 162.	手机很好用，流畅，拍照功能强大，反向充电还没试
# 163.	发货速度快，是正品！玩了一整天电量还满满的，玩游戏很顺畅，支持华为！
# 164.	很不错，功能强大，设计完美，外观漂亮，爱不释手，很喜欢。
# 165.	非常好的服务，华为手机棒棒的。赠品也很喜欢！五星好评，实至名归！
# 166.	很好！支持华为！为店家周到服务点赞！
# 167.	价格虽然跟旗舰店一样但送了好多实用的礼品，很划算！赞一个！
# 168.	给家人买的手机，家人很喜欢，物流很快，两三天就到了，手机屏幕大，以后会继续支持！
# 169.	宝贝收到了，能够这么低的价格买到心仪的手机，真是太意外了，运行速度嗖嗖的，还送了好多礼品，赞！
# 170.	手机收到啦，很快用上，原来华为手机里的所有一键全到新手机，速度很快，颜色漂亮，点赞！
# 171.	华为的手机绝对好，美观，电池好用。店家赠送小礼物都不错，还有一年保险，绝对诚实价！
# 172.	确实挺不错的，华为的牌子也特别的硬，很喜欢。
# 173.	手机到货非常快啊  屏幕很清晰  样式我也很喜欢 满意
# 174.	手机发货很快，收到也很满意，赠品也不错，值得购买
# 175.	手机屏幕大小合适  一直用的华为手机  家里也一直用  很实用 也很划算
# 176.	一直想换手机了，原来的MATE9用了有点卡，京东上看到这个，马上就上手了，价格也很满意，原装。还行，很流畅
# 177.	手机不错哦，速度很快，音量什么都很好。超喜欢。是朋友推荐买的，不必苹果差
# 178.	手机收到了，运行速度很快，手机像素很高，送的赠品很给力，五星好评！
# 179.	手机很不错，用的很顺手，网速很快。不卡机，应该是正品。
# 180.	手机收到了，一点也不卡，质量很好，是正品，还送了好多礼品，真心不错
# 181.	收到后赶忙用了一天安装了一堆软件 确实速度很快  手感也不错  流畅

# %%
with open('d:\\789.csv','w+',encoding='utf-8') as f:
    for i in comment:
        data = str(i) + ',\n'
        f.write(data)#将数据用csv格式储存到d盘
