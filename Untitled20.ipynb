# %%
#%%
import subprocess
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
import re,time

#%%
command = "\"C:\\Program Files (x86)\\Google\\Chrome\\Application\\chrome.exe\" --remote-debugging-port=9242 --user-data-dir=C:\chrome_profile"
print(command)

#%%
retcode = subprocess.Popen(command,shell=True)

#%%
time.sleep(10)

#%%
chrome_options = Options()

#%%
chrome_options.add_experimental_option("debuggerAddress", "127.0.0.1:9242")

#%%
driver = webdriver.Chrome(options=chrome_options)

#%%
driver.get("https://item.jd.com/34640640658.html")

#%%
driver.find_element_by_xpath(r'//*[@id="detail"]/div[1]/ul/li[5]').click()

#%%
reobj = re.compile(r'<p class="comment-con">([\s\S]*?)</p>')

#%%

#%%
comment = []
count = 1

#%% 
# driver.find_element_by_xpath(r'//*[@id="comment-0"]/div[13]/div/div/a[6]').click()

# driver.find_element_by_link_text(u"下一页").click()


# if 'click' in dir(driver.find_element_by_link_text(u"下一页")):
#     driver.find_element_by_link_text(u"下一页").click()
#     print("true")



#%%
def next_page(driver):
    # driver.find_element_by_link_text(u"下一页").click()
    parent = driver.find_element_by_css_selector('.ui-page')
    try:
        parent.find_element_by_link_text(u"下一页").click()
    except:
        time.sleep(2)
        page_num = parent.find_element_by_link_text(u"下一页").get_attribute('rel') 
        # ActionChains(driver).send_keys(Keys.SPACE).perform()
        # time.sleep(2)
        parent.find_element_by_link_text(page_num).click()
        # driver.find_element_by_link_text(u"下一页").click()

#%%
while True:
    html = driver.page_source
    result = reobj.finditer(html)
    if not result:
        print("找不到评论结束")
    for i in result:
        comment.append(i.group(1))
        print(str(count) + ".\t" + i.group(1))
        count += 1
    # for i in result:
    #     z = reobj1.search(i.group(1))
    #     try:

    #         comment.append(z.group(1))
    #         print(str(count) + ".\t" + z.group(1))
    #         count += 1
    #     except:
    #         pass
    # retry = 0
    
    try:
        next_page(driver)
    except:
        try:
            next_page(driver)
        except:
            break
##-----------------
#    for p in Page_turning.find_elements_by_tag_name("a"):
#        ActionChains(d).move_to_element(p).perform()
#    retry = 0
#    for j in range(0,5):
#        try:
#            time.sleep(2)
#            p.click()
#        except:
#            retry += 1
#    if retry > 4:
#        print(retry)
#        break                

#%%
# result = reobj.finditer(html)
# for i in result:
#     print(i)

#%%
print(i.group(1))



#%%
len(comment)

#%%
with open('d:\\ssssss9.csv','w+',encoding='utf-8') as f:
    for i in comment:
        data = str(i) + ',\n'
        f.write(data)

#%%
# Out:
# "C:\Program Files (x86)\Google\Chrome\Application\chrome.exe" --remote-debugging-port=9242 --user-data-dir=C:\chrome_profile
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-fe291dc5dbdb> in <module>()
#     115
#     116 #%%
# --> 117 print(i.group(1))
#     118
#     119
#
# NameError: name 'i' is not defined
